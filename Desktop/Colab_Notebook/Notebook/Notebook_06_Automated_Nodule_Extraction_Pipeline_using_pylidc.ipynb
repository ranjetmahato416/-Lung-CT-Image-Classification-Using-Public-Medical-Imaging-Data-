# %% [markdown]
# ###Objective
#
# Generate the final dataset that will be used for deep learning.
#
# Input:
#
# * Original CT DICOM scans
# * pylidc annotations
#
# Output:
#
# * Cropped 3D lung nodule volumes (.npy)
# * Metadata CSV containing labels and patch paths

# %% [markdown]
# ##1. mount Google Drive

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(
    r"C:\Users\Dell\Desktop\Colab_Notebook\Dataset"
)

# %% [markdown]
# ##2. Install Packages

# %%
# !pip install -q pylidc pydicom scipy scikit-image tqdm

# %% [markdown]
# ##3. Import Required Libraries

# %%
config_path = PROJECT_ROOT / ".pylidcrc"
config_content = """
[dicom]
path = C:\\Users\\Dell\\Desktop\\Colab_Notebook\\Dataset\\Raw
"""

RAW_PATH = PROJECT_ROOT / "Raw"

PROCESSED_PATH = PROJECT_ROOT / "Processed"

XML_PATH = PROJECT_ROOT / "ANNOTATION_STAGING"

LOG_FILE = PROCESSED_PATH / "processing_log.csv"

DATASET_FILE = PROCESSED_PATH / "nodule_dataset.csv"

PATCH_PATH = PROCESSED_PATH / "NodulePatches"

MASK_PATH = PROCESSED_PATH / "Masks"

PATCH_PATH.mkdir(parents=True, exist_ok=True)

MASK_PATH.mkdir(parents=True, exist_ok=True)

PROCESSED_PATH.mkdir(parents=True, exist_ok=True)

CNN_PATH = PROJECT_ROOT / "CNN_Dataset"

CNN_PATH.mkdir(
    parents=True,
    exist_ok=True
)

config_path.write_text(config_content)

print("Created:", config_path)

print(config_path.read_text())
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import configparser
if not hasattr(configparser, "SafeConfigParser"):
    configparser.SafeConfigParser = configparser.ConfigParser

from tqdm import tqdm
# Out:
# Created: C:\Users\Dell\Desktop\Colab_Notebook\Dataset\.pylidcrc
#
# [dicom]
# path = C:\Users\Dell\Desktop\Colab_Notebook\Dataset\Raw

# %%
from pathlib import Path

config_path = Path.home() / ".pylidcrc"

config_content = f"""
[dicom]
path = {RAW_PATH}
"""

with open(config_path, "w") as f:
    f.write(config_content)

print("Created:", config_path)
print(config_content)
# Out:
# Created: C:\Users\Dell\.pylidcrc
#
# [dicom]
# path = C:\Users\Dell\Desktop\Colab_Notebook\Dataset\Raw

# %%
from pathlib import Path

config_path = Path.home() / "pylidc.conf"

config_content = """
[dicom]
path = C:/Users/Dell/Desktop/Colab_Notebook/Dataset/Raw
"""

with open(config_path, "w") as f:
    f.write(config_content)

print("Created:", config_path)
print(config_content)
# Out:
# Created: C:\Users\Dell\pylidc.conf
#
# [dicom]
# path = C:/Users/Dell/Desktop/Colab_Notebook/Dataset/Raw

# %% [markdown]
# ##4. NumPy Compatibility

# %%
if not hasattr(np, "int"):
    np.int = int

if not hasattr(np, "float"):
    np.float = float

if not hasattr(np, "bool"):
    np.bool = bool
import pylidc as pl

# %%
print("Raw exists      :", RAW_PATH.exists())
print("XML exists      :", XML_PATH.exists())
print("Processed exists:", PROCESSED_PATH.exists())

print()

print("Patients found:",
      len(list(RAW_PATH.glob("LIDC-IDRI-*"))))

print("XML files:",
      len(list(XML_PATH.glob("*.xml"))))
# Out:
# Raw exists      : True
# XML exists      : True
# Processed exists: True
#
# Patients found: 510
# XML files: 0

# %%
import pylidc

print("pylidc version:", pylidc.__version__)
print("Installed at:", pylidc.__file__)
# Out:
# pylidc version: 0.2.3
# Installed at: c:\Users\Dell\anaconda3\envs\lidc\Lib\site-packages\pylidc\__init__.py

# %%
import pylidc as pl

print("Database scans:", pl.query(pl.Scan).count())
# Out:
# Database scans: 1018

# %% [markdown]
# ##5. Dataset Path

# %%
from pathlib import Path
from datetime import datetime
import pandas as pd


if LOG_FILE.exists():

    processing_log = pd.read_csv(LOG_FILE)

else:

    processing_log = pd.DataFrame(
        columns=[
            "PatientID",
            "Status",
            "Nodules",
            "ProcessedTime",
            "Error"
        ]
    )

if DATASET_FILE.exists():

    dataset_df = pd.read_csv(DATASET_FILE)

else:

    dataset_df = pd.DataFrame()

processed_patients = set(

    processing_log.loc[
        processing_log.Status=="Completed",
        "PatientID"
    ]

)

print("Already processed:",len(processed_patients))
# Out:
# Already processed: 1010

# %% [markdown]
# ##6. Load Database

# %%
scans = pl.query(pl.Scan).all()

print("Total scans:", len(scans))
# Out:
# Total scans: 1018

# %% [markdown]
# ##7. Create Patient Lookup

# %%
patient_folders = sorted([
    p.name
    for p in RAW_PATH.iterdir()
    if p.is_dir()
])

print(patient_folders)
# Out:
# ['LIDC-IDRI-0502', 'LIDC-IDRI-0503', 'LIDC-IDRI-0504', 'LIDC-IDRI-0505', 'LIDC-IDRI-0506', 'LIDC-IDRI-0507', 'LIDC-IDRI-0508', 'LIDC-IDRI-0509', 'LIDC-IDRI-0510', 'LIDC-IDRI-0511', 'LIDC-IDRI-0512', 'LIDC-IDRI-0513', 'LIDC-IDRI-0514', 'LIDC-IDRI-0515', 'LIDC-IDRI-0516', 'LIDC-IDRI-0517', 'LIDC-IDRI-0518', 'LIDC-IDRI-0519', 'LIDC-IDRI-0520', 'LIDC-IDRI-0521', 'LIDC-IDRI-0522', 'LIDC-IDRI-0523', 'LIDC-IDRI-0524', 'LIDC-IDRI-0525', 'LIDC-IDRI-0526', 'LIDC-IDRI-0527', 'LIDC-IDRI-0528', 'LIDC-IDRI-0529', 'LIDC-IDRI-0530', 'LIDC-IDRI-0531', 'LIDC-IDRI-0532', 'LIDC-IDRI-0533', 'LIDC-IDRI-0534', 'LIDC-IDRI-0535', 'LIDC-IDRI-0536', 'LIDC-IDRI-0537', 'LIDC-IDRI-0538', 'LIDC-IDRI-0539', 'LIDC-IDRI-0540', 'LIDC-IDRI-0541', 'LIDC-IDRI-0542', 'LIDC-IDRI-0543', 'LIDC-IDRI-0544', 'LIDC-IDRI-0545', 'LIDC-IDRI-0546', 'LIDC-IDRI-0547', 'LIDC-IDRI-0548', 'LIDC-IDRI-0549', 'LIDC-IDRI-0550', 'LIDC-IDRI-0551', 'LIDC-IDRI-0552', 'LIDC-IDRI-0553', 'LIDC-IDRI-0554', 'LIDC-IDRI-0555', 'LIDC-IDRI-0556', 'LIDC-IDRI-0557', 'LID
', 'LIDC-IDRI-0661', 'LIDC-IDRI-0662', 'LIDC-IDRI-0663', 'LIDC-IDRI-0664', 'LIDC-IDRI-0665', 'LIDC-IDRI-0666', 'LIDC-IDRI-0667', 'LIDC-IDRI-0668', 'LIDC-IDRI-0669', 'LIDC-IDRI-0670', 'LIDC-IDRI-0671', 'LIDC-IDRI-0672', 'LIDC-IDRI-0673', 'LIDC-IDRI-0674', 'LIDC-IDRI-0675', 'LIDC-IDRI-0676', 'LIDC-IDRI-0677', 'LIDC-IDRI-0678', 'LIDC-IDRI-0679', 'LIDC-IDRI-0680', 'LIDC-IDRI-0681', 'LIDC-IDRI-0682', 'LIDC-IDRI-0683', 'LIDC-IDRI-0684', 'LIDC-IDRI-0685', 'LIDC-IDRI-0686', 'LIDC-IDRI-0687', 'LIDC-IDRI-0688', 'LIDC-IDRI-0689', 'LIDC-IDRI-0690', 'LIDC-IDRI-0691', 'LIDC-IDRI-0692', 'LIDC-IDRI-0693', 'LIDC-IDRI-0694', 'LIDC-IDRI-0695', 'LIDC-IDRI-0696', 'LIDC-IDRI-0697', 'LIDC-IDRI-0698', 'LIDC-IDRI-0699', 'LIDC-IDRI-0700', 'LIDC-IDRI-0701', 'LIDC-IDRI-0702', 'LIDC-IDRI-0703', 'LIDC-IDRI-0704', 'LIDC-IDRI-0705', 'LIDC-IDRI-0706', 'LIDC-IDRI-0707', 'LIDC-IDRI-0708', 'LIDC-IDRI-0709', 'LIDC-IDRI-0710', 'LIDC-IDRI-0711', 'LIDC-IDRI-0712', 'LIDC-IDRI-0713', 'LIDC-IDRI-0714', 'LIDC-IDRI-0715', 'LIDC-IDRI-0716', 'LIDC-IDRI-0717', 'LIDC-IDRI-0718', 'LIDC-IDRI-0719', 'LIDC-IDRI-0720', 'LIDC-IDRI-0721', 'LIDC-IDRI-0722', 'LIDC-IDRI-0723', 'LIDC-IDRI-0724', 'LI ...

# %% [markdown]
# ##8. Keep Only Available Patients

# %%
available_scans = []

for scan in scans:

    if scan.patient_id in patient_folders:

        available_scans.append(scan)

print("Available scans:", len(available_scans))
# Out:
# Available scans: 510

# %%
##9. Select First Patient

# %%
scan = available_scans[0]

print("Patient:", scan.patient_id)

print("Study UID:", scan.study_instance_uid)

print("Series UID:", scan.series_instance_uid)
# Out:
# Patient: LIDC-IDRI-0502
# Study UID: 1.3.6.1.4.1.14519.5.2.1.6279.6001.246309121384607847712377186777
# Series UID: 1.3.6.1.4.1.14519.5.2.1.6279.6001.259018373683540453277752706262

# %% [markdown]
# ##10. Cluser Annotations

# %%
clusters = scan.cluster_annotations()

print("Clusters:", len(clusters))

for i, cluster in enumerate(clusters):

    print(
        f"Cluster {i+1}:",
        len(cluster),
        "reader(s)"
    )
# Out:
# Clusters: 1
# Cluster 1: 1 reader(s)

# %% [markdown]
# ##11. Select One Physical Nodule

# %%
cluster = clusters[0]

print("Number of annotations:", len(cluster))
# Out:
# Number of annotations: 1

# %% [markdown]
# ##12. Consensus Malignancy

# %%
malignancy_scores = [
    ann.malignancy
    for ann in cluster
]

print("Reader Scores:")

print(malignancy_scores)

print()

print(
    "Mean:",
    np.mean(malignancy_scores)
)

print(
    "Median:",
    np.median(malignancy_scores)
)
# Out:
# Reader Scores:
# [3]
#
# Mean: 3.0
# Median: 3.0

# %% [markdown]
# ##13. Load CT Volume

# %%
volume = scan.to_volume()

print("Volume shape:", volume.shape)

print("Data type:", volume.dtype)

print("Minimum:", volume.min())

print("Maximum:", volume.max())
# Out:
# Loading dicom files ... This may take a moment.
# Volume shape: (512, 512, 130)
# Data type: int16
# Minimum: -3024
# Maximum: 1916

# %% [markdown]
# ##14. Generate Consensus Mask
# pylidc provides multiple annotations from multiple radiologists. We need to combine them into a single consensus mask.

# %%
from pylidc.utils import consensus

PADDING = 20

mask, bbox, masks = consensus(
    cluster,
    clevel=0.5,
    pad=[
        (PADDING, PADDING),
        (PADDING, PADDING),
        (2, 2)
    ]
)

print("Mask shape:", mask.shape)

print("Bounding box:")
print(bbox)
# Out:
# Mask shape: (46, 49, 6)
# Bounding box:
# (slice(np.int64(389), np.int64(435), None), slice(np.int64(183), np.int64(232), None), slice(np.int64(49), np.int64(55), None))

# %% [markdown]
# ##15. Verify Mask Dimensions

# %%
print("CT volume:")
print(volume.shape)

print()

print("Mask:")
print(mask.shape)
# Out:
# CT volume:
# (512, 512, 130)
#
# Mask:
# (46, 49, 6)

# %% [markdown]
# ##16. Extract Nodule Patch

# %%
nodule_patch = volume[
    bbox[0],
    bbox[1],
    bbox[2]
].copy()

print(
    "Nodule patch shape:",
    nodule_patch.shape
)
# Out:
# Nodule patch shape: (46, 49, 6)

# %% [markdown]
# ##17. Confirm Patch and Mask Alignment

# %%
print(
    "Patch:",
    nodule_patch.shape
)

print(
    "Mask:",
    mask.shape
)
# Out:
# Patch: (46, 49, 6)
# Mask: (46, 49, 6)

# %% [markdown]
# ##18. Visualize Extracted Nodule

# %%
middle = nodule_patch.shape[2] // 2


plt.figure(figsize=(12,5))


plt.subplot(1,2,1)

plt.imshow(
    nodule_patch[:,:,middle],
    cmap="gray"
)

plt.title("Extracted CT Nodule")

plt.axis("off")



plt.subplot(1,2,2)

plt.imshow(
    mask[:,:,middle],
    cmap="gray"
)

plt.title("Consensus Mask")

plt.axis("off")


plt.show()

# %% [markdown]
# ##19. Apply Mask

# %%
binary_mask = mask.astype(bool)

masked_patch = nodule_patch.copy()

masked_patch[~binary_mask] = -1024

masked_patch = np.clip(masked_patch, -1000, 400)

# %% [markdown]
# ####Visualize:

# %%
plt.figure(figsize=(5,5))

plt.imshow(
    masked_patch[:,:,middle],
    cmap="gray"
)

plt.title("Masked Nodule")

plt.axis("off")

plt.show()

# %% [markdown]
# ##20. Save First Test Patch

# %%
test_file = (
    PATCH_PATH /
    f"{scan.patient_id}_nodule_test.npy"
)


np.save(
    test_file,
    masked_patch
)


print(
    "Saved:",
    test_file
)
# Out:
# Saved: C:\Users\Dell\Desktop\Colab_Notebook\Dataset\Processed\NodulePatches\LIDC-IDRI-0502_nodule_test.npy

# %% [markdown]
# ##21. Create Extraction Function
#
# ####Function 1: Convert malignancy score to binary label

# %%
def malignancy_label(score):

    if score >= 4:
        return 1   # malignant

    else:
        return 0   # benign

# %% [markdown]
# ##22. Create Nodule Extraction Function

# %%
def extract_nodule(
    volume,
    scan,
    cluster,
    save_path,
    nodule_id
):

    try:

        # Generate consensus mask
        PADDING = 20

        mask, bbox, masks = consensus(
            cluster,
            clevel=0.5,
            pad=[
                (PADDING, PADDING),
                (PADDING, PADDING),
                (2, 2)
            ]
        )

        # Ignore extremely tiny nodules
        if mask.sum() < 50:
            return None



        # Crop CT
        patch = volume[
            bbox[0],
            bbox[1],
            bbox[2]
        ]

        binary_mask = mask.astype(bool)

        raw_patch = patch.copy()

        masked_patch = patch.copy()

        masked_patch[~binary_mask] = -1024

        masked_patch = np.clip(masked_patch, -1000, 400)


        # Save
        filename = (
            f"{scan.patient_id}_"
            f"nodule_{nodule_id:03d}.npy"
        )


        filepath = save_path / filename


        np.save(
            filepath,
            raw_patch.astype(np.int16)
        )

        mask_file = (
            MASK_PATH /
            f"{scan.patient_id}_nodule_{nodule_id:03d}_mask.npy"
        )

        np.save(mask_file, binary_mask.astype(np.uint8))



        # Malignancy information

        scores = [
            ann.malignancy
            for ann in cluster
        ]


        mean_malignancy = np.mean(scores)


        return {

            "PatientID":
                scan.patient_id,

            "NoduleID":
                nodule_id,

            "PatchPath":
                str(filepath),

            "PatchShape":
                str(patch.shape),

            "Readers":
                len(cluster),

            "MeanMalignancy":
                mean_malignancy,

            "MedianMalignancy":
                np.median(scores),

            "CancerLabel":
                malignancy_label(
                    mean_malignancy
                ),

            "MaskedPatchPath": str(mask_file),

            "MaskPath": str(mask_file),
            "MaskVoxelCount" : int(mask.sum())

        }


    except Exception as e:

        print(
            "Failed:",
            scan.patient_id,
            nodule_id,
            e
        )

        return None

# %% [markdown]
# ##23. Test Function on Current Patient

# %%
# Load CT once
volume = scan.to_volume()
test_result = extract_nodule(
    volume,
    scan,
    cluster,
    PATCH_PATH,
    1
)

test_result
# Out:
# Loading dicom files ... This may take a moment.

# %% [markdown]
# ##24. Process All Available Scans

# %%
from tqdm import tqdm

all_records = []

for scan in tqdm(
    available_scans,
    desc="Processing patients"
):

    # Resume support
    if scan.patient_id in processed_patients:
        print(f"Skipping {scan.patient_id}")
        continue

    print(f"\nProcessing: {scan.patient_id}")

    # Check if patient already exists in dataset CSV
    existing_dataset_patients = set()

    if DATASET_FILE.exists():

        existing = pd.read_csv(
            DATASET_FILE,
            usecols=["PatientID"]
        )

        existing_dataset_patients = set(
            existing["PatientID"]
        )

        if scan.patient_id in existing_dataset_patients:

            print(f"{scan.patient_id} already exists in dataset. Skipping.")

            continue

    try:

        # Load CT only once
        volume = scan.to_volume()

        clusters = scan.cluster_annotations()

        patient_records = []

        for idx, cluster in enumerate(clusters):

            result = extract_nodule(
                volume,
                scan,
                cluster,
                PATCH_PATH,
                idx + 1
            )

            if result is not None:

              if not Path(result["PatchPath"]).exists():

                  raise FileNotFoundError(result["PatchPath"])

              if not Path(result["MaskPath"]).exists():

                  raise FileNotFoundError(result["MaskPath"])

              patient_records.append(result)

        # Save immediately
        if len(patient_records) > 0:

            patient_df = pd.DataFrame(patient_records)

            if DATASET_FILE.exists():

                patient_df.to_csv(
                    DATASET_FILE,
                    mode="a",
                    header=False,
                    index=False
                )

            else:

                patient_df.to_csv(
                    DATASET_FILE,
                    index=False
                )

            all_records.extend(patient_records)

        processing_log.loc[len(processing_log)] = [
            scan.patient_id,
            "Completed",
            len(patient_records),

            datetime.now(),
            ""
        ]

    except Exception as e:

        print(f"ERROR: {scan.patient_id}")
        print(e)

        processing_log.loc[len(processing_log)] = [
            scan.patient_id,
            "Failed",
            0,

            datetime.now(),

            str(e)
        ]

    # Save checkpoint after every patient
    processing_log.to_csv(LOG_FILE, index=False)
# Out:
# Processing patients:   0%|          | 0/510 [00:00<?, ?it/s]
# Processing: LIDC-IDRI-0502
# Loading dicom files ... This may take a moment.
# Processing patients:   0%|          | 1/510 [00:03<29:46,  3.51s/it]
# Skipping LIDC-IDRI-0503
# Skipping LIDC-IDRI-0504
# Skipping LIDC-IDRI-0505
#
# Processing: LIDC-IDRI-0506
# Loading dicom files ... This may take a moment.
# Processing patients:   1%|          | 5/510 [00:07<10:42,  1.27s/it]
# Processing: LIDC-IDRI-0507
# LIDC-IDRI-0507 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0508
# Skipping LIDC-IDRI-0509
# Skipping LIDC-IDRI-0510
#
# Processing: LIDC-IDRI-0511
# Loading dicom files ... This may take a moment.
# Processing patients:   2%|▏         | 10/510 [00:09<07:00,  1.19it/s]
# Processing: LIDC-IDRI-0512
# Loading dicom files ... This may take a moment.
# Processing patients:   2%|▏         | 11/510 [00:12<09:32,  1.15s/it]
# Processing: LIDC-IDRI-0513
# Loading dicom files ... This may take a moment.
# Processing patients:   2%|▏         | 12/510 [00:26<27:10,  3.27s/it]
# Processing: LIDC-IDRI-0514
# Loading dicom files ... This may take a moment.
# Processing patients:   3%|▎         | 13/510 [00:30<29:15,  3.53s/it]
# Processing: LIDC-IDRI-0515
# LIDC-IDRI-0515 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0516
# Loading dicom files ... This may take a moment.
# Processing patients:   3%|▎         | 15/510 [00:33<23:14,  2.82s/it]
# Skipping LIDC-IDRI-0517
# Skipping LIDC-IDRI-0518
#
# Processing: LIDC-IDRI-0519
# Loading dicom files ... This may take a moment.
# Processing patients:   4%|▎         | 18/510 [00:40<20:47,  2.54s/it]
# Processing: LIDC-IDRI-0520
# LIDC-IDRI-0520 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0521
# LIDC-IDRI-0521 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0522
# LIDC-IDRI-0522 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0523
#
# Processing: LIDC-IDRI-0524
# LIDC-IDRI-0524 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0525
# LIDC-IDRI-0525 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0526
# Skipping LIDC-IDRI-0527
#
# Processing: LIDC-IDRI-0528
# Loading dicom files ... This may take a moment.
# Processing patients:   5%|▌         | 27/510 [00:43<09:05,  1.13s/it]
# Processing: LIDC-IDRI-0529
# LIDC-IDRI-0529 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0530
#
# Processing: LIDC-IDRI-0531
# Loading dicom files ... This may take a moment.
# Processing patients:   6%|▌         | 30/510 [00:46<08:44,  1.09s/it]
# Processing: LIDC-IDRI-0532
# LIDC-IDRI-0532 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0533
# Skipping LIDC-IDRI-0534
# Skipping LIDC-IDRI-0535
#
# Processing: LIDC-IDRI-0536
# Loading dicom files ... This may take a moment.
# Processing patients:   7%|▋         | 35/510 [00:58<12:30,  1.58s/it]
# Skipping LIDC-IDRI-0537
#
# Processing: LIDC-IDRI-0538
# LIDC-IDRI-0538 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0539
# LIDC-IDRI-0539 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0540
# Loading dicom files ... This may take a moment.
# Processing patients:   8%|▊         | 39/510 [01:07<13:27,  1.72s/it]
# Skipping LIDC-IDRI-0541
# Skipping LIDC-IDRI-0542
#
# Processing: LIDC-IDRI-0543
# LIDC-IDRI-0543 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0544
# Loading dicom files ... This may take a moment.
# Processing patients:   8%|▊         | 43/510 [01:09<10:41,  1.37s/it]
# Processing: LIDC-IDRI-0545
# LIDC-IDRI-0545 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0546
# LIDC-IDRI-0546 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0547
#
# Processing: LIDC-IDRI-0548
# Loading dicom files ... This may take a moment.
# Processing patients:   9%|▉         | 47/510 [01:11<08:59,  1.17s/it]
# Skipping LIDC-IDRI-0549
# Skipping LIDC-IDRI-0550
#
# Processing: LIDC-IDRI-0551
# LIDC-IDRI-0551 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0552
#
# Processing: LIDC-IDRI-0553
# LIDC-IDRI-0553 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0554
#
# Processing: LIDC-IDRI-0555
# LIDC-IDRI-0555 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0556
#
# Processing: LIDC-IDRI-0557
# LIDC-IDRI-0557 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0558
# LIDC-IDRI-0558 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0559
# Loading dicom files ... This may take a moment.
# Processing patients:  11%|█▏        | 58/510 [01:15<05:27,  1.38it/s]
# Skipping LIDC-IDRI-0560
#
# Processing: LIDC-IDRI-0561
# Loading dicom files ... This may take a moment.
# Processing patients:  12%|█▏        | 60/510 [01:22<07:37,  1.02s/it]
# Skipping LIDC-IDRI-0562
#
# Processing: LIDC-IDRI-0563
# Loading dicom files ... This may take a moment.
# Processing patients:  12%|█▏        | 62/510 [01:27<09:45,  1.31s/it]
# Processing: LIDC-IDRI-0564
# Loading dicom files ... This may take a moment.
# Processing patients:  12%|█▏        | 63/510 [01:38<16:10,  2.17s/it]
# Skipping LIDC-IDRI-0565
# Skipping LIDC-IDRI-0566
#
# Processing: LIDC-IDRI-0567
# LIDC-IDRI-0567 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0568
# Skipping LIDC-IDRI-0569
# Skipping LIDC-IDRI-0570
# Skipping LIDC-IDRI-0571
# Skipping LIDC-IDRI-0572
#
# Processing: LIDC-IDRI-0573
# Loading dicom files ... This may take a moment.
# Processing patients:  14%|█▍        | 72/510 [01:40<08:18,  1.14s/it]
# Skipping LIDC-IDRI-0574
# Skipping LIDC-IDRI-0575
# Skipping LIDC-IDRI-0576
# Skipping LIDC-IDRI-0577
# Skipping LIDC-IDRI-0578
# Skipping LIDC-IDRI-0579
#
# Processing: LIDC-IDRI-0580
# LIDC-IDRI-0580 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-
already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0921
# LIDC-IDRI-0921 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0920
# LIDC-IDRI-0920 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0919
#
# Processing: LIDC-IDRI-0918
# Loading dicom files ... This may take a moment.
# Processing patients:  45%|████▌     | 230/510 [04:05<03:35,  1.30it/s]
# Skipping LIDC-IDRI-0917
# Skipping LIDC-IDRI-0916
# Skipping LIDC-IDRI-0915
# Skipping LIDC-IDRI-0914
#
# Processing: LIDC-IDRI-0913
# LIDC-IDRI-0913 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0912
# Skipping LIDC-IDRI-0911
# Skipping LIDC-IDRI-0910
#
# Processing: LIDC-IDRI-0909
# LIDC-IDRI-0909 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0908
# LIDC-IDRI-0908 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0907
# LIDC-IDRI-0907 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0906
#
# Processing: LIDC-IDRI-0905
# LIDC-IDRI-0905 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0904
#
# Processing: LIDC-IDRI-0903
# Loading dicom files ... This may take a moment.
# Processing patients:  48%|████▊     | 245/510 [04:09<02:06,  2.10it/s]
# Skipping LIDC-IDRI-0902
#
# Processing: LIDC-IDRI-0901
# Loading dicom files ... This may take a moment.
# Processing patients:  48%|████▊     | 247/510 [04:12<02:31,  1.74it/s]
# Processing: LIDC-IDRI-0900
# Loading dicom files ... This may take a moment.
# Processing patients:  49%|████▊     | 248/510 [04:22<05:24,  1.24s/it]
# Skipping LIDC-IDRI-0899
# Skipping LIDC-IDRI-0898
#
# Processing: LIDC-IDRI-0897
# Loading dicom files ... This may take a moment.
# Processing patients:  49%|████▉     | 251/510 [04:33<07:40,  1.78s/it]
# Skipping LIDC-IDRI-0896
# Skipping LIDC-IDRI-0895
# Skipping LIDC-IDRI-0894
# Skipping LIDC-IDRI-0893
# Skipping LIDC-IDRI-0892
#
# Processing: LIDC-IDRI-0891
# Loading dicom files ... This may take a moment.
# Processing patients:  50%|█████     | 257/510 [04:37<05:29,  1.30s/it]
# Skipping LIDC-IDRI-0890
#
# Processing: LIDC-IDRI-0889
# Loading dicom files ... This may take a moment.
# Processing patients:  51%|█████     | 259/510 [04:40<05:32,  1.32s/it]
# Processing: LIDC-IDRI-0888
# LIDC-IDRI-0888 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0887
# Loading dicom files ... This may take a moment.
# Processing patients:  51%|█████     | 261/510 [04:43<05:42,  1.37s/it]
# Skipping LIDC-IDRI-0886
#
# Processing: LIDC-IDRI-0885
# Loading dicom files ... This may take a moment.
# Processing patients:  52%|█████▏    | 263/510 [04:47<06:28,  1.57s/it]
# Processing: LIDC-IDRI-0884
# LIDC-IDRI-0884 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0883
# LIDC-IDRI-0883 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0882
# LIDC-IDRI-0882 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0881
# Loading dicom files ... This may take a moment.
# Processing patients:  52%|█████▏    | 267/510 [04:51<05:14,  1.29s/it]
# Skipping LIDC-IDRI-0880
# Skipping LIDC-IDRI-0879
#
# Processing: LIDC-IDRI-0878
# Loading dicom files ... This may take a moment.
# Processing patients:  53%|█████▎    | 270/510 [04:56<05:32,  1.38s/it]
# Processing: LIDC-IDRI-0877
# Loading dicom files ... This may take a moment.
# Processing patients:  53%|█████▎    | 271/510 [05:01<07:36,  1.91s/it]
# Processing: LIDC-IDRI-0876
# Loading dicom files ... This may take a moment.
# Processing patients:  53%|█████▎    | 272/510 [05:16<14:59,  3.78s/it]
# Processing: LIDC-IDRI-0875
# LIDC-IDRI-0875 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-
already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0714
# LIDC-IDRI-0714 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0713
# Skipping LIDC-IDRI-0712
#
# Processing: LIDC-IDRI-0711
# Loading dicom files ... This may take a moment.
# Processing patients:  86%|████████▌ | 437/510 [07:33<01:00,  1.20it/s]
# Processing: LIDC-IDRI-0710
# Loading dicom files ... This may take a moment.
# Processing patients:  88%|████████▊ | 450/510 [07:43<00:41,  1.45it/s]
# Skipping LIDC-IDRI-0709
# Skipping LIDC-IDRI-0708
# Skipping LIDC-IDRI-0707
# Skipping LIDC-IDRI-0706
# Skipping LIDC-IDRI-0705
#
# Processing: LIDC-IDRI-0704
# LIDC-IDRI-0704 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0703
# LIDC-IDRI-0703 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0702
# LIDC-IDRI-0702 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0701
# LIDC-IDRI-0701 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0700
# LIDC-IDRI-0700 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0699
# LIDC-IDRI-0699 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0698
# LIDC-IDRI-0698 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0697
# LIDC-IDRI-0697 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0696
# LIDC-IDRI-0696 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0695
# Skipping LIDC-IDRI-0694
#
# Processing: LIDC-IDRI-0693
# Loading dicom files ... This may take a moment.
# Processing patients:  89%|████████▉ | 455/510 [07:46<00:36,  1.52it/s]
# Skipping LIDC-IDRI-0692
#
# Processing: LIDC-IDRI-0691
# Loading dicom files ... This may take a moment.
#
# Processing: LIDC-IDRI-0690
# Loading dicom files ... This may take a moment.
# Processing patients:  90%|████████▉ | 458/510 [07:52<00:44,  1.16it/s]
# Processing: LIDC-IDRI-0689
# Loading dicom files ... This may take a moment.
# Processing patients:  90%|█████████ | 460/510 [07:58<00:59,  1.20s/it]
# Processing: LIDC-IDRI-0688
# LIDC-IDRI-0688 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0687
# Skipping LIDC-IDRI-0686
#
# Processing: LIDC-IDRI-0685
# Loading dicom files ... This may take a moment.
# Processing patients:  91%|█████████ | 463/510 [08:00<00:52,  1.12s/it]
# Processing: LIDC-IDRI-0684
# LIDC-IDRI-0684 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0683
# Loading dicom files ... This may take a moment.
# Processing patients:  91%|█████████ | 465/510 [08:03<00:53,  1.19s/it]
# Processing: LIDC-IDRI-0682
# LIDC-IDRI-0682 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0681
# LIDC-IDRI-0681 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0680
#
# Processing: LIDC-IDRI-0679
# Loading dicom files ... This may take a moment.
# Processing patients:  92%|█████████▏| 469/510 [08:06<00:42,  1.03s/it]
# Skipping LIDC-IDRI-0678
# Skipping LIDC-IDRI-0677
#
# Processing: LIDC-IDRI-0676
# LIDC-IDRI-0676 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0675
# Skipping LIDC-IDRI-0674
#
# Processing: LIDC-IDRI-0673
# LIDC-IDRI-0673 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0672
# LIDC-IDRI-0672 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0671
#
# Processing: LIDC-IDRI-0670
# LIDC-IDRI-0670 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0669
# LIDC-IDRI-0669 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0668
# Loading dicom files ... This may take a moment.
# Processing patients:  94%|█████████▍| 480/510 [08:09<00:17,  1.72it/s]
# Processing: LIDC-IDRI-0667
# Loading dicom files ... This may take a moment.
# Processing patients:  94%|█████████▍| 481/510 [08:19<00:36,  1.26s/it]
# Skipping LIDC-IDRI-0666
#
# Processing: LIDC-IDRI-0665
# Loading dicom files ... This may take a moment.
# Processing patients:  95%|█████████▍| 483/510 [08:34<01:01,  2.27s/it]
# Processing: LIDC-IDRI-0664
# LIDC-IDRI-0664 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0663
# LIDC-IDRI-0663 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0662
# Skipping LIDC-IDRI-0661
# Skipping LIDC-IDRI-0660
# Skipping LIDC-IDRI-0659
#
# Processing: LIDC-IDRI-0658
# LIDC-IDRI-0658 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0657
# LIDC-IDRI-0657 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0656
#
# Processing: LIDC-IDRI-0655
# LIDC-IDRI-0655 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0654
#
# Processing: LIDC-IDRI-0653
# Loading dicom files ... This may take a moment.
# Processing patients:  98%|█████████▊| 501/510 [08:37<00:06,  1.31it/s]
# Skipping LIDC-IDRI-0652
#
# Processing: LIDC-IDRI-0651
# LIDC-IDRI-0651 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0650
# LIDC-IDRI-0650 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0649
#
# Processing: LIDC-IDRI-0648
# LIDC-IDRI-0648 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0647
# LIDC-IDRI-0647 already exists in dataset. Skipping.
#
# Processing: LIDC-IDRI-0646
# Loading dicom files ... This may take a moment.
# Processing patients: 100%|██████████| 510/510 [08:43<00:00,  1.03s/it]
# Skipping LIDC-IDRI-0645
#
# Processing: LIDC-IDRI-0644
# LIDC-IDRI-0644 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0643
# Skipping LIDC-IDRI-0642
# Skipping LIDC-IDRI-0641
# Skipping LIDC-IDRI-0640
#
# Processing: LIDC-IDRI-0639
# LIDC-IDRI-0639 already exists in dataset. Skipping.
# Skipping LIDC-IDRI-0638

# %%
if (len(processing_log) % 25)==0:

    print()

    print("="*50)

    print(processing_log.Status.value_counts())

    print()

    print("Dataset size:",
          len(pd.read_csv(DATASET_FILE)))

    print("="*50)

# %%
if len(all_records) > 0:

    patient_df = pd.DataFrame(patient_records)

    if DATASET_FILE.exists():

        patient_df.to_csv(

            DATASET_FILE,

            mode="a",

            header=False,

            index=False

        )

    else:

        patient_df.to_csv(

            DATASET_FILE,

            index=False

        )

# %% [markdown]
# ##25. Convert Results to DataFrame

# %%
dataset_df = pd.read_csv(DATASET_FILE)

print(dataset_df.shape)

dataset_df.head()


print(
    "Total extracted nodules:",
    len(dataset_df)
)
# Out:
# (1643, 11)
# Total extracted nodules: 1643

# %% [markdown]
# ##26. Check Class Distribution

# %%
dataset_df["CancerLabel"].value_counts()
# Out:
# CancerLabel
# 0    1439
# 1     204
# Name: count, dtype: int64

# %% [markdown]
# ##27. Save Metadata CSV

# %%
metadata_output = (
    PROCESSED_PATH /
    "nodule_dataset.csv"
)


dataset_df.to_csv(
    metadata_output,
    index=False
)


print(
    "Saved:",
    metadata_output
)
# Out:
# Saved: C:\Users\Dell\Desktop\Colab_Notebook\Dataset\Processed\nodule_dataset.csv

# %%
processing_log.loc[len(processing_log)] = [

    scan.patient_id,

    "Completed",

    len(all_records),
    datetime.now(),

    ""

]

processing_log.to_csv(

    LOG_FILE,

    index=False

)

# %% [markdown]
# ##28. Import Required Packages

# %%
import gc
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ##29. Create Output Directories

# %%
PATCH_PATH = (
    PROCESSED_PATH /
    "NodulePatches"
)

PATCH_PATH.mkdir(
    parents=True,
    exist_ok=True
)

# %% [markdown]
# ##30. Metadata File

# %%
metadata_csv = (
    PROCESSED_PATH /
    "nodule_dataset.csv"
)

# %% [markdown]
# ##31. Resume Capability
# ####If Colab disconnects after processing 500 patients the notebook simply continues.

# %%
processed_patients = set()

if metadata_csv.exists():

    existing = pd.read_csv(metadata_csv)

    processed_patients = set(
        existing["PatientID"].unique()
    )

print(
    "Already processed:",
    len(processed_patients)
)
# Out:
# Already processed: 668

# %% [markdown]
# ##32. Metadata Buffer

# %%
records = []

# %% [markdown]
# ##33. Optimized Main Loop

# %%
for scan in tqdm(
    scans,
    desc="Processing Patients"
):

    if scan.patient_id not in patient_folders:
        continue

    if scan.patient_id in processed_patients:
        print(f"Skipping {scan.patient_id}")
        continue

    print(f"\nProcessing {scan.patient_id}")

    try:

        # Load CT only once
        volume = scan.to_volume()

        clusters = scan.cluster_annotations()

        patient_records = []

        for idx, cluster in enumerate(clusters):

            result = extract_nodule(
                volume,
                scan,
                cluster,
                PATCH_PATH,
                idx + 1
            )

            if result is not None:
                patient_records.append(result)

        # Save metadata immediately
        if len(patient_records) > 0:

            df = pd.DataFrame(patient_records)

            if metadata_csv.exists():

                df.to_csv(
                    metadata_csv,
                    mode="a",
                    header=False,
                    index=False
                )

            else:

                df.to_csv(
                    metadata_csv,
                    index=False
                )

        del volume
        gc.collect()

    except Exception as e:

        print(
            scan.patient_id,
            e
        )
# Out:
# Processing Patients:   0%|          | 0/1018 [00:00<?, ?it/s]
# Processing LIDC-IDRI-0502
# Loading dicom files ... This may take a moment.
# Processing Patients:  50%|████▉     | 508/1018 [00:01<00:01, 279.26it/s]
# Skipping LIDC-IDRI-0503
# Skipping LIDC-IDRI-0504
# Skipping LIDC-IDRI-0505
#
# Processing LIDC-IDRI-0506
# Loading dicom files ... This may take a moment.
#
# Processing LIDC-IDRI-0507
# Loading dicom files ... This may take a moment.
# Processing Patients:  50%|█████     | 513/1018 [00:16<00:21, 23.19it/s]
# Skipping LIDC-IDRI-0508
# Skipping LIDC-IDRI-0509
# Skipping LIDC-IDRI-0510
#
# Processing LIDC-IDRI-0511
# Loading dicom files ... This may take a moment.
# Processing Patients:  51%|█████     | 517/1018 [00:18<00:26, 18.88it/s]
# Processing LIDC-IDRI-0512
# Loading dicom files ... This may take a moment.
#
# Processing LIDC-IDRI-0513
# Loading dicom files ... This may take a moment.
# Processing Patients:  51%|█████     | 519/1018 [00:33<01:05,  7.61it/s]
# Processing LIDC-IDRI-0514
# Loading dicom files ... This may take a moment.
# Processing Patients:  51%|█████     | 520/1018 [00:35<01:15,  6.61it/s]
# Processing LIDC-IDRI-0515
# Loading dicom files ... This may take a moment.
#
# Processing LIDC-IDRI-0516
# Loading dicom files ... This may take a moment.
# Skipping LIDC-IDRI-0517
# Skipping LIDC-IDRI-0518
#
# Processing LIDC-IDRI-0519
# Loading dicom files ... This may take a moment.
#
# Processing LIDC-IDRI-0520
# Loading dicom files ... This may take a moment.
# Processing Patients:  52%|█████▏    | 526/1018 [01:04<03:34,  2.29it/s]
# Processing LIDC-IDRI-0521
# Loading dicom files ... This may take a moment.
# Processing Patients:  52%|█████▏    | 527/1018 [01:11<04:28,  1.83it/s]
# Processing LIDC-IDRI-0522
# Loading dicom files ... This may take a moment.
# Skipping LIDC-IDRI-0523
#
# Processing LIDC-IDRI-0524
# Loading dicom files ... This may take a moment.
# Processing Patients:  52%|█████▏    | 530/1018 [01:30<07:11,  1.13it/s]
# Processing LIDC-IDRI-0525
# Loading dicom files ... This may take a moment.
# Processing Patients:  52%|█████▏    | 531/1018 [01:42<09:42,  1.20s/it]
# Skipping LIDC-IDRI-0526
# Skipping LIDC-IDRI-0527
#
# Processing LIDC-IDRI-0528
# Loading dicom files ... This may take a moment.
# Processing Patients:  52%|█████▏    | 534/1018 [01:46<09:33,  1.19s/it]
# Processing LIDC-IDRI-0529
# Loading dicom files ... This may take a moment.
# Processing Patients:  53%|█████▎    | 535/1018 [02:11<18:55,  2.35s/it]
# Skipping LIDC-IDRI-0530
#
# Processing LIDC-IDRI-0531
# Loading dicom files ... This may take a moment.
# Processing Patients:  53%|█████▎    | 537/1018 [02:15<18:17,  2.28s/it]
# Processing LIDC-IDRI-0532
# Loading dicom files ... This may take a moment.
# Processing Patients:  53%|█████▎    | 539/1018 [02:27<22:47,  2.85s/it]
# Skipping LIDC-IDRI-0533
# Skipping LIDC-IDRI-0534
# Skipping LIDC-IDRI-0535
#
# Processing LIDC-IDRI-0536
# Loading dicom files ... This may take a moment.
# Processing Patients:  53%|█████▎    | 542/1018 [02:40<25:18,  3.19s/it]
# Skipping LIDC-IDRI-0537
#
# Processing LIDC-IDRI-0538
# Loading dicom files ... This may take a moment.
# Processing Patients:  53%|█████▎    | 544/1018 [02:59<34:11,  4.33s/it]
# Processing LIDC-IDRI-0539
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▎    | 545/1018 [03:07<37:31,  4.76s/it]
# Processing LIDC-IDRI-0540
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▎    | 547/1018 [03:15<36:12,  4.61s/it]
# Skipping LIDC-IDRI-0541
# Skipping LIDC-IDRI-0542
#
# Processing LIDC-IDRI-0543
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▍    | 549/1018 [03:31<43:06,  5.52s/it]
# Processing LIDC-IDRI-0544
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▍    | 550/1018 [03:34<39:31,  5.07s/it]
# Processing LIDC-IDRI-0545
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▍    | 551/1018 [03:48<52:00,  6.68s/it]
# Processing LIDC-IDRI-0546
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▍    | 552/1018 [03:59<59:44,  7.69s/it]
# Skipping LIDC-IDRI-0547
#
# Processing LIDC-IDRI-0548
# Loading dicom files ... This may take a moment.
# Processing Patients:  54%|█████▍    | 554/1018 [04:03<42:48,  5.54s/it]
# Skipping LIDC-IDRI-0549
# Skipping LIDC-IDRI-0550
#
# Processing LIDC-IDRI-0551
# Loading dicom files ... This may take a moment.
# Processing Patients:  55%|█████▍    | 557/1018 [04:27<50:41,  6.60s/it]
# Skipping LIDC-IDRI-0552
#
# Processing LIDC-IDRI-0553
# Loading dicom files ... This may take a moment.
# Processing Patients:  55%|█████▍    | 559/1018 [04:53<1:05:29,  8.56s/it]
# Skipping LIDC-IDRI-0554
#
# Processing LIDC-IDRI-0555
# Loading dicom files ... This may take a moment.
# Processing Patients:  55%|█████▌    | 561/1018 [05:06<59:57,  7.87s/it]
# Skipping LIDC-IDRI-0556
#
# Processing LIDC-IDRI-0557
# Loading dicom files ... This may take a moment.
# Processing Patients:  55%|█████▌    | 563/1018 [05:29<1:08:17,  9.01s/it]
# Processing LIDC-IDRI-0558
# Loading dicom files ... This may take a moment.
# Processing Patients:  55%|█████▌    | 564/1018 [05:45<1:17:40, 10.26s/it]
# Processing LIDC-IDRI-0559
# Loading dicom files ... This may take a moment.
# Processing Patients:  56%|█████▌    | 565/1018 [05:55<1:16:40, 10.16s/it]
# Skipping LIDC-IDRI-0560
#
# Processing LIDC-IDRI-0561
# Loading dicom files ... This may take a moment.
# Processing Patients:  56%|█████▌    | 567/1018 [06:03<59:22,  7.90s/it]
# Skipping LIDC-IDRI-0562
#
# Processing LIDC-IDRI-0563
# Loading dicom files ... This may take a moment.
# Processing Patients:  56%|█████▌    | 569/1018 [06:12<51:12,  6.84s/it]
# Processing LIDC-IDRI-0564
# Loading dicom files ... This may take a moment.
# Processing Patients:  56%|█████▌    | 570/1018 [06:35<1:13:31,  9.85s/it]
# Skipping LIDC-IDRI-0565
# Skipping LIDC-IDRI-0566
#
# Processing LIDC-IDRI-0567
# Loading dicom files ... This may take a moment.
# Processing Patients:  56%|█████▋    | 573/1018 [06:49<55:53,  7.54s/it]
# Skipping LIDC-IDRI-0568
# Skipping LIDC-IDRI-0569
# Skipping LIDC-IDRI-0570
# Skipping LIDC-IDRI-0571
# Skipping LIDC-IDRI-0572
#
# Processing LIDC-IDRI-0573
# Loading dicom files ... This may take a moment.
# Processing Patients:  57%|█████▋    | 579/1018 [06:54<27:27,  3.75s/it]
# Skipping LIDC-IDRI-0574
# Skipping LIDC-IDRI-0575
# Skipping LIDC-IDRI-0576
# Skipping LIDC-IDRI-0577
# Skipping LIDC-IDRI-0578
# Skipping LIDC-IDRI-0579
#
# Processing LIDC-IDRI-0580
# Loading dicom files ... This may take a moment.
# Processing Patients:  58%|█████▊    | 586/1018 [07:06<20:00,  2.78s/it]
# Processing LIDC-IDRI-0581
# Loading dicom files ... This may take a moment.
# Processing Patients:  58%|█████▊    | 587/1018 [07:13<22:12,  3.09s/it]
# Processing LIDC-IDRI-0582
# Loading dicom files ... This may take a moment.
# Processing Patients:  58%|█████▊    | 588/1018 [08:01<59:14,  8.27s/it]
# Skipping LIDC-IDRI-0583
# Skipping LIDC-IDRI-0584
# Skipping LIDC-IDRI-0586
# Skipping LIDC-IDRI-0587
# Skipping LIDC-IDRI-0588
#
# Processing LIDC-IDRI-0589
# Loading dicom files ... This may take a moment.
# Processing Patients:  58%|█████▊    | 594/1018 [08:06<32:32,  4.60s/it]
# Processing LIDC-IDRI-0590
# Loading dicom files ... This may take a moment.
# Processing Patients:  58%|█████▊    | 595/1018 [08:22<40:44,  5.78s/it]
# Processing LIDC-IDRI-0591
# Loading dicom files ... This may take a moment.
# Processing Patients:  59%|█████▊    | 596/1018 [08:28<40:43,  5.79s/it]
# Skipping LIDC-IDRI-0592
#
# Processing LIDC-IDRI-0593
# Loading dicom files ... This may take a moment.
# Processing Patients:  59%|█████▊    | 598/1018 [08:30<31:58,  4.57s/it]
# Skipping LIDC-IDRI-0594
# Skipping LIDC-IDRI-0595
#
# Processing LIDC-IDRI-0596
# Loading dicom files ... This may take a moment.
# Processing Patients:  59%|█████▉    | 601/1018 [08:39<27:44,  3.99s/it]
# Skipping LIDC-IDRI-0597
# Skipping LIDC-IDRI-0598
#
# Processing LIDC-IDRI-0599
# Loading dicom files ... This may take a moment.
# Processing Patients:  59%|█████▉    | 604/1018 [08:50<26:42,  3.87s/it]
# Processing LIDC-IDRI-0600
# Loading dicom files ... This may take a moment.
# Processing Patients:  59%|█████▉    | 605/1018 [08:56<27:59,  4.07s/it]
# Skipping LIDC-IDRI-0601
# Skipping LIDC-IDRI-0602
#
# Processing LIDC-IDRI-0603
# Loading dicom files ... This may take a moment.
# Processing Patients:  60%|█████▉    | 608/1018 [08:58<19:46,  2.89s/it]
# Skipping LIDC-IDRI-0604
# Skipping LIDC-IDRI-0605
#
# Processing LIDC-IDRI-0606
# Loading dicom files ... This may take a moment.
# Processing Patients:  60%|██████    | 611/1018 [09:17<27:52,  4.11s/it]
# Skipping LIDC-IDRI-0607
#
# Processing LIDC-IDRI-0608
# Loading dicom files ... This may take a moment.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing Patients:  60%|██████    | 613/1018 [09:26<28:06,  4.16s/it]
# Processing LIDC-IDRI-0609
# Loading dicom files ... This may take a moment.
# Processing Patients:  60%|██████    | 614/1018 [09:38<35:49,  5.32s/it]
# Skipping LIDC-IDRI-0610
#
# Processing LIDC-IDRI-0611
# Loading dicom files ... This may take a moment.
# Processing Patients:  61%|██████    | 616/1018 [09:40<27:14,  4.07s/it]
# Processing LIDC-IDRI-0612
# Loading dicom files ... This may take a moment.
# Processing Patients:  61%|██████    | 617/1018 [09:43<26:07,  3.91s/it]
# Skipping LIDC-IDRI-0613
#
# Processing LIDC-IDRI-0614
# Loading dicom files ... This may take a moment.
# Processing Patients:  61%|██████    | 619/1018 [10:00<35:45,  5.38s/it]
# Skipping LIDC-IDRI-0615
#
# Processing LIDC-IDRI-0616
# Loading dicom files ... This may take a moment.
# Processing Patients:  61%|██████    | 621/1018 [10:03<27:23,  4.14s/it]
# Skipping LIDC-IDRI-0617
# Skipping LIDC-IDRI-0618
# Skipping LIDC-IDRI-0619
# Skipping LIDC-IDRI-0620
#
# Processing LIDC-IDRI-0621
# Loading dicom files ... This may take a moment.
# Processing Patients:  61%|██████▏   | 626/1018 [10:27<29:04,  4.45s/it]
# Processing LIDC-IDRI-0622
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 627/1018 [10:35<32:33,  4.99s/it]
# Processing LIDC-IDRI-0623
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 628/1018 [10:58<50:24,  7.76s/it]
# Skipping LIDC-IDRI-0624
#
# Processing LIDC-IDRI-0625
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 630/1018 [11:29<1:06:00, 10.21s/it]
# Processing LIDC-IDRI-0626
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 631/1018 [11:36<1:01:48,  9.58s/it]
# Processing LIDC-IDRI-0627
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 632/1018 [11:42<57:07,  8.88s/it]
# Skipping LIDC-IDRI-0628
#
# Processing LIDC-IDRI-0629
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 634/1018 [11:53<49:13,  7.69s/it]
# Skipping LIDC-IDRI-0630
#
# Processing LIDC-IDRI-0631
# Loading dicom files ... This may take a moment.
# Processing Patients:  62%|██████▏   | 636/1018 [12:15<56:21,  8.85s/it]
# Processing LIDC-IDRI-0632
# Loading dicom files ... This may take a moment.
# Processing Patients:  63%|██████▎   | 637/1018 [12:21<51:53,  8.17s/it]
# Skipping LIDC-IDRI-0633
# Skipping LIDC-IDRI-0634
# Skipping LIDC-IDRI-0635
# Skipping LIDC-IDRI-0636
#
# Processing LIDC-IDRI-0637
# Loading dicom files ... This may take a moment.
# Processing Patients:  63%|██████▎   | 642/1018 [12:53<45:05,  7.20s/it]
# Skipping LIDC-IDRI-1012
# Skipping LIDC-IDRI-1011
# Skipping LIDC-IDRI-1010
# Skipping LIDC-IDRI-1009
# Skipping LIDC-IDRI-1008
# Skipping LIDC-IDRI-1007
# Skipping LIDC-IDRI-1006
# Skipping LIDC-IDRI-1005
#
# Processing LIDC-IDRI-1004
# Loading dicom files ... This may take a moment.
# Processing Patients:  64%|██████▍   | 651/1018 [13:20<28:43,  4.70s/it]
# Skipping LIDC-IDRI-1003
#
# Processing LIDC-IDRI-1002
# Loading dicom files ... This may take a moment.
# Processing Patients:  64%|██████▍   | 653/1018 [13:44<35:24,  5.82s/it]
# Skipping LIDC-IDRI-1001
# Skipping LIDC-IDRI-1000
# Skipping LIDC-IDRI-0999
# Skipping LIDC-IDRI-0998
#
# Processing LIDC-IDRI-0997
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▍   | 658/1018 [14:12<34:39,  5.78s/it]
# Processing LIDC-IDRI-0996
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▍   | 659/1018 [14:23<37:25,  6.26s/it]
# Processing LIDC-IDRI-0995
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▍   | 660/1018 [14:28<36:15,  6.08s/it]
# Processing LIDC-IDRI-0994
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▍   | 661/1018 [14:55<54:11,  9.11s/it]
# Skipping LIDC-IDRI-0993
#
# Processing LIDC-IDRI-0992
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▌   | 663/1018 [14:58<40:58,  6.93s/it]
# Processing LIDC-IDRI-0991
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▌   | 664/1018 [15:04<39:32,  6.70s/it]
# Processing LIDC-IDRI-0990
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▌   | 665/1018 [15:11<39:46,  6.76s/it]
# Processing LIDC-IDRI-0989
# Loading dicom files ... This may take a moment.
# Processing Patients:  65%|██████▌   | 666/1018 [15:17<38:20,  6.54s/it]
# Processing LIDC-IDRI-0988
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▌   | 667/1018 [15:23<38:03,  6.50s/it]
# Processing LIDC-IDRI-0987
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▌   | 668/1018 [15:36<48:06,  8.25s/it]
# Skipping LIDC-IDRI-0986
#
# Processing LIDC-IDRI-0985
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▌   | 670/1018 [15:47<40:36,  7.00s/it]
# Skipping LIDC-IDRI-0984
# Skipping LIDC-IDRI-0983
#
# Processing LIDC-IDRI-0982
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▌   | 673/1018 [16:00<33:11,  5.77s/it]
# Processing LIDC-IDRI-0981
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▌   | 674/1018 [16:10<37:36,  6.56s/it]
# Skipping LIDC-IDRI-0980
#
# Processing LIDC-IDRI-0979
# Loading dicom files ... This may take a moment.
# Processing Patients:  66%|██████▋   | 676/1018 [16:15<29:00,  5.09s/it]
# Processing LIDC-IDRI-0978
# Loading dicom files ... This may take a moment.
# Processing Patients:  67%|██████▋   | 677/1018 [16:28<37:34,  6.61s/it]
# Skipping LIDC-IDRI-0977
# Skipping LIDC-IDRI-0976
#
# Processing LIDC-IDRI-0975
# Loading dicom files ... This may take a moment.
# Processing Patients:  67%|██████▋   | 680/1018 [16:38<29:20,  5.21s/it]
# Skipping LIDC-IDRI-0974
# Skipping LIDC-IDRI-0973
# Skipping LIDC-IDRI-0972
# Skipping LIDC-IDRI-0971
#
# Processing LIDC-IDRI-0970
# Loading dicom files ... This may take a moment.
# Processing Patients:  67%|██████▋   | 685/1018 [16:44<17:04,  3.08s/it]
# Processing LIDC-IDRI-0969
# Loading dicom files ... This may take a moment.
# Processing Patients:  67%|██████▋   | 686/1018 [16:56<23:42,  4.29s/it]
# Processing LIDC-IDRI-0968
# Loading dicom files ... This may take a moment.
# Processing Patients:  67%|██████▋   | 687/1018 [17:11<32:52,  5.96s/it]
# Processing LIDC-IDRI-0967
# Loading dicom files ... This may take a moment.
# Processing Patients:  68%|██████▊   | 688/1018 [17:16<31:30,  5.73s/it]
# Skipping LIDC-IDRI-0966
#
# Processing LIDC-IDRI-0965
# Loading dicom files ... This may take a moment.
# Processing Patients:  68%|██████▊   | 690/1018 [17:32<35:12,  6.44s/it]
# Processing LIDC-IDRI-0964
# Loading dicom files ... This may take a moment.
# Processing Patients:  68%|██████▊   | 691/1018 [17:37<33:26,  6.14s/it]
# Processing LIDC-IDRI-0963
# Loading dicom files ... This may take a moment.
# Processing Patients:  68%|██████▊   | 692/1018 [17:54<46:30,  8.56s/it]
# Skipping LIDC-IDRI-0962
# Skipping LIDC-IDRI-0961
#
# Processing LIDC-IDRI-0960
# Loading dicom files ... This may take a moment.
# Processing Patients:  68%|██████▊   | 695/1018 [18:07<35:06,  6.52s/it]
# Skipping LIDC-IDRI-0959
# Skipping LIDC-IDRI-0958
#
# Processing LIDC-IDRI-0957
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▊   | 698/1018 [18:09<22:13,  4.17s/it]
# Processing LIDC-IDRI-0956
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▊   | 699/1018 [18:16<24:29,  4.61s/it]
# Processing LIDC-IDRI-0955
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 700/1018 [18:26<29:39,  5.60s/it]
# Processing LIDC-IDRI-0954
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 701/1018 [18:31<28:49,  5.46s/it]
# Processing LIDC-IDRI-0953
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 702/1018 [18:40<33:10,  6.30s/it]
# Processing LIDC-IDRI-0952
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 703/1018 [18:42<28:12,  5.37s/it]
# Skipping LIDC-IDRI-0951
#
# Processing LIDC-IDRI-0950
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 705/1018 [18:48<22:10,  4.25s/it]
# Skipping LIDC-IDRI-0949
#
# Processing LIDC-IDRI-0948
# Loading dicom files ... This may take a moment.
# Processing Patients:  69%|██████▉   | 707/1018 [18:51<17:07,  3.30s/it]
# Processing LIDC-IDRI-0947
# Loading dicom files ... This may take a moment.
# Processing Patients:  70%|██████▉   | 708/1018 [19:03<25:51,  5.01s/it]
# Skipping LIDC-IDRI-0946
# Skipping LIDC-IDRI-0945
# Skipping LIDC-IDRI-0944
#
# Processing LIDC-IDRI-0943
# Loading dicom files ... This may take a moment.
# Processing Patients:  70%|██████▉   | 712/1018 [19:12<18:28,  3.62s/it]
# Skipping LIDC-IDRI-0942
#
# Processing LIDC-IDRI-0941
# Loading dicom files ... This may take a moment.
# Processing Patients:  70%|███████   | 714/1018 [19:25<22:26,  4.43s/it]
# Processing LIDC-IDRI-0940
# Loading dicom files ... This may take a moment.
# Processing Patients:  70%|███████   | 715/1018 [19:38<29:32,  5.85s/it]
# Processing LIDC-IDRI-0939
# Loading dicom files ... This may take a moment.
# Processing Patients:  70%|███████   | 716/1018 [19:49<34:34,  6.87s/it]
# Skipping LIDC-IDRI-0938
#
# Processing LIDC-IDRI-0937
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 718/1018 [19:52<24:03,  4.81s/it]
# Processing LIDC-IDRI-0936
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 719/1018 [19:57<24:31,  4.92s/it]
# Skipping LIDC-IDRI-0935
#
# Processing LIDC-IDRI-0934
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 721/1018 [19:59<17:42,  3.58s/it]
# Skipping LIDC-IDRI-0933
#
# Processing LIDC-IDRI-0932
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 723/1018 [20:04<15:21,  3.12s/it]
# Processing LIDC-IDRI-0931
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 724/1018 [20:09<17:08,  3.50s/it]
# Processing LIDC-IDRI-0930
# Loading dicom files ... This may take a moment.
# Processing Patients:  71%|███████   | 725/1018 [20:14<18:25,  3.77s/it]
# Skipping LIDC-IDRI-0929
# Skipping LIDC-IDRI-0928
#
# Processing LIDC-IDRI-0927
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 728/1018 [20:17<11:33,  2.39s/it]
# Skipping LIDC-IDRI-0926
#
# Processing LIDC-IDRI-0925
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 730/1018 [20:25<14:35,  3.04s/it]
# Processing LIDC-IDRI-0924
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 731/1018 [20:35<19:54,  4.16s/it]
# Processing LIDC-IDRI-0923
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 732/1018 [20:56<37:21,  7.84s/it]
# Processing LIDC-IDRI-0922
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 733/1018 [21:15<48:57, 10.31s/it]
# Processing LIDC-IDRI-0921
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 734/1018 [21:40<1:06:11, 13.99s/it]
# Processing LIDC-IDRI-0920
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 735/1018 [22:04<1:18:29, 16.64s/it]
# Skipping LIDC-IDRI-0919
#
# Processing LIDC-IDRI-0918
# Loading dicom files ... This may take a moment.
# Processing Patients:  72%|███████▏  | 737/1018 [22:11<50:55, 10.87s/it]
# Skipping LIDC-IDRI-0917
# Skipping LIDC-IDRI-0916
# Skipping LIDC-IDRI-0915
# Skipping LIDC-IDRI-0914
#
# Processing LIDC-IDRI-0913
# Loading dicom files ... This may take a moment.
# Processing Patients:  73%|███████▎  | 742/1018 [22:31<31:04,  6.76s/it]
# Skipping LIDC-IDRI-0912
# Skipping LIDC-IDRI-0911
# Skipping LIDC-IDRI-0910
#
# Processing LIDC-IDRI-0909
# Loading dicom files ... This may take a moment.
# Processing Patients:  73%|███████▎  | 746/1018 [22:57<30:02,  6.63s/it]
# Processing LIDC-IDRI-0908
# Loading dicom files ... This may take a moment.
# Processing Patients:  73%|███████▎  | 747/1018 [23:19<39:06,  8.66s/it]
# Processing LIDC-IDRI-0907
# Loading dicom files ... This may take a moment.
# Processing Patients:  73%|███████▎  | 748/1018 [23:33<42:26,  9.43s/it]
# Skipping LIDC-IDRI-0906
#
# Processing LIDC-IDRI-0905
# Loading dicom files ... This may take a moment.
# Processing Patients:  74%|███████▎  | 750/1018 [23:47<38:43,  8.67s/it]
# Skipping LIDC-IDRI-0904
#
# Processing LIDC-IDRI-0903
# Loading dicom files ... This may take a moment.
# Processing Patients:  74%|███████▍  | 752/1018 [23:52<30:14,  6.82s/it]
# Skipping LIDC-IDRI-0902
#
# Processing LIDC-IDRI-0901
# Loading dicom files ... This may take a moment.
# Processing Patients:  74%|███████▍  | 754/1018 [23:57<24:26,  5.56s/it]
# Processing LIDC-IDRI-0900
# Loading dicom files ... This may take a moment.
# Processing Patients:  74%|███████▍  | 755/1018 [24:17<35:09,  8.02s/it]
# Skipping LIDC-IDRI-0899
# Skipping LIDC-IDRI-0898
#
# Processing LIDC-IDRI-0897
# Loading dicom files ... This may take a moment.
# Processing Patients:  74%|███████▍  | 758/1018 [24:37<32:29,  7.50s/it]
# Skipping LIDC-IDRI-0896
# Skipping LIDC-IDRI-0895
# Skipping LIDC-IDRI-0894
# Skipping LIDC-IDRI-0893
# Skipping LIDC-IDRI-0892
#
# Processing LIDC-IDRI-0891
# Loading dicom files ... This may take a moment.
# Processing Patients:  75%|███████▌  | 764/1018 [24:43<16:29,  3.90s/it]
# Skipping LIDC-IDRI-0890
#
# Processing LIDC-IDRI-0889
# Loading dicom files ... This may take a moment.
# Processing Patients:  75%|███████▌  | 766/1018 [24:48<15:04,  3.59s/it]
# Processing LIDC-IDRI-0888
# Loading dicom files ... This may take a moment.
# Processing Patients:  75%|███████▌  | 767/1018 [24:57<18:12,  4.35s/it]
# Processing LIDC-IDRI-0887
# Loading dicom files ... This may take a moment.
# Processing Patients:  75%|███████▌  | 768/1018 [25:01<17:36,  4.23s/it]
# Skipping LIDC-IDRI-0886
#
# Processing LIDC-IDRI-0885
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▌  | 770/1018 [25:05<14:55,  3.61s/it]
# Processing LIDC-IDRI-0884
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▌  | 771/1018 [25:11<16:43,  4.06s/it]
# Processing LIDC-IDRI-0883
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▌  | 772/1018 [25:20<20:49,  5.08s/it]
# Processing LIDC-IDRI-0882
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▌  | 773/1018 [25:29<23:32,  5.77s/it]
# Processing LIDC-IDRI-0881
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▌  | 774/1018 [25:31<20:19,  5.00s/it]
# Skipping LIDC-IDRI-0880
# Skipping LIDC-IDRI-0879
#
# Processing LIDC-IDRI-0878
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▋  | 777/1018 [25:36<12:55,  3.22s/it]
# Processing LIDC-IDRI-0877
# Loading dicom files ... This may take a moment.
# Processing Patients:  76%|███████▋  | 778/1018 [25:41<14:26,  3.61s/it]
# Processing LIDC-IDRI-0876
# Loading dicom files ... This may take a moment.
# Processing Patients:  77%|███████▋  | 779/1018 [26:00<27:59,  7.03s/it]
# Processing LIDC-IDRI-0875
# Loading dicom files ... This may take a moment.
# Processing Patients:  77%|███████▋  | 780/1018 [26:19<39:04,  9.85s/it]
# Processing LIDC-IDRI-0874
# Loading dicom files ... This may take a moment.
# Processing Patients:  77%|███████▋  | 781/1018 [26:55<1:05:10, 16.50s/it]
# Skipping LIDC-IDRI-0873
# Skipping LIDC-IDRI-0872
# Skipping LIDC-IDRI-0871
# Skipping LIDC-IDRI-0870
# Skipping LIDC-IDRI-0869
# Skipping LIDC-IDRI-0868
#
# Processing LIDC-IDRI-0867
# Loading dicom files ... This may take a moment.
# Processing Patients:  77%|███████▋  | 788/1018 [27:21<28:12,  7.36s/it]
# Skipping LIDC-IDRI-0866
# Skipping LIDC-IDRI-0865
# Skipping LIDC-IDRI-0864
#
# Processing LIDC-IDRI-0863
# Loading dicom files ... This may take a moment.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing Patients:  78%|███████▊  | 792/1018 [27:35<22:06,  5.87s/it]
# Processing LIDC-IDRI-0862
# Loading dicom files ... This may take a moment.
# Processing Patients:  78%|███████▊  | 793/1018 [27:40<21:35,  5.76s/it]
# Skipping LIDC-IDRI-0861
# Skipping LIDC-IDRI-0860
#
# Processing LIDC-IDRI-0859
# Loading dicom files ... This may take a moment.
# Processing Patients:  78%|███████▊  | 796/1018 [27:56<20:44,  5.61s/it]
# Processing LIDC-IDRI-0858
# Loading dicom files ... This may take a moment.
# Processing Patients:  78%|███████▊  | 797/1018 [28:30<35:15,  9.57s/it]
# Skipping LIDC-IDRI-0857
#
# Processing LIDC-IDRI-0856
# Loading dicom files ... This may take a moment.
# Processing Patients:  78%|███████▊  | 799/1018 [28:55<38:00, 10.42s/it]
# Skipping LIDC-IDRI-0855
#
# Processing LIDC-IDRI-0854
# Loading dicom files ... This may take a moment.
# Processing Patients:  79%|███████▊  | 801/1018 [29:23<40:58, 11.33s/it]
# Processing LIDC-IDRI-0853
# Loading dicom files ... This may take a moment.
# Processing Patients:  79%|███████▉  | 802/1018 [29:28<37:30, 10.42s/it]
# Skipping LIDC-IDRI-0852
#
# Processing LIDC-IDRI-0851
# Loading dicom files ... This may take a moment.
# Processing Patients:  79%|███████▉  | 804/1018 [29:45<34:25,  9.65s/it]
# Skipping LIDC-IDRI-0850
# Skipping LIDC-IDRI-0849
# Skipping LIDC-IDRI-0848
#
# Processing LIDC-IDRI-0847
# Loading dicom files ... This may take a moment.
# Processing Patients:  79%|███████▉  | 808/1018 [29:51<20:13,  5.78s/it]
# Processing LIDC-IDRI-0846
# Loading dicom files ... This may take a moment.
# Processing Patients:  79%|███████▉  | 809/1018 [30:00<21:47,  6.25s/it]
# Processing LIDC-IDRI-0845
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|███████▉  | 810/1018 [30:22<31:05,  8.97s/it]
# Processing LIDC-IDRI-0844
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|███████▉  | 811/1018 [30:49<43:12, 12.52s/it]
# Processing LIDC-IDRI-0843
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|███████▉  | 812/1018 [31:21<58:05, 16.92s/it]
# Processing LIDC-IDRI-0842
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|███████▉  | 813/1018 [31:29<49:56, 14.62s/it]
# Skipping LIDC-IDRI-0841
#
# Processing LIDC-IDRI-0840
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|████████  | 815/1018 [31:36<34:19, 10.15s/it]
# Processing LIDC-IDRI-0839
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|████████  | 816/1018 [31:55<40:54, 12.15s/it]
# Skipping LIDC-IDRI-0838
#
# Processing LIDC-IDRI-0837
# Loading dicom files ... This may take a moment.
# Processing Patients:  80%|████████  | 818/1018 [32:23<42:56, 12.88s/it]
# Skipping LIDC-IDRI-0836
# Skipping LIDC-IDRI-0835
# Skipping LIDC-IDRI-0834
# Skipping LIDC-IDRI-0833
# Skipping LIDC-IDRI-0832
#
# Processing LIDC-IDRI-0831
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████  | 824/1018 [32:47<23:35,  7.30s/it]
# Processing LIDC-IDRI-0830
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████  | 825/1018 [33:03<27:05,  8.42s/it]
# Processing LIDC-IDRI-0829
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████  | 826/1018 [33:17<29:53,  9.34s/it]
# Processing LIDC-IDRI-0828
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████  | 827/1018 [33:31<32:29, 10.21s/it]
# Processing LIDC-IDRI-0827
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████▏ | 828/1018 [33:58<42:56, 13.56s/it]
# Processing LIDC-IDRI-0826
# Loading dicom files ... This may take a moment.
# Processing Patients:  81%|████████▏ | 829/1018 [34:23<51:01, 16.20s/it]
# Processing LIDC-IDRI-0825
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 830/1018 [34:36<48:51, 15.59s/it]
# Skipping LIDC-IDRI-0824
# Skipping LIDC-IDRI-0823
# Skipping LIDC-IDRI-0822
#
# Processing LIDC-IDRI-0821
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 834/1018 [35:01<30:50, 10.06s/it]
# Skipping LIDC-IDRI-0820
#
# Processing LIDC-IDRI-0819
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 836/1018 [35:13<26:44,  8.81s/it]
# Processing LIDC-IDRI-0818
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 837/1018 [35:19<25:33,  8.47s/it]
# Processing LIDC-IDRI-0817
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 838/1018 [35:30<26:47,  8.93s/it]
# Processing LIDC-IDRI-0816
# Loading dicom files ... This may take a moment.
# Processing Patients:  82%|████████▏ | 839/1018 [35:44<29:35,  9.92s/it]
# Processing LIDC-IDRI-0815
# Loading dicom files ... This may take a moment.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing Patients:  83%|████████▎ | 840/1018 [35:58<32:32, 10.97s/it]
# Skipping LIDC-IDRI-0814
# Skipping LIDC-IDRI-0813
# Skipping LIDC-IDRI-0812
#
# Processing LIDC-IDRI-0811
# Loading dicom files ... This may take a moment.
# Processing Patients:  83%|████████▎ | 844/1018 [36:24<24:22,  8.40s/it]
# Processing LIDC-IDRI-0810
# Loading dicom files ... This may take a moment.
# Processing Patients:  83%|████████▎ | 845/1018 [36:45<30:34, 10.60s/it]
# Skipping LIDC-IDRI-0809
#
# Processing LIDC-IDRI-0808
# Loading dicom files ... This may take a moment.
# Processing Patients:  83%|████████▎ | 847/1018 [37:00<27:04,  9.50s/it]
# Skipping LIDC-IDRI-0807
# Skipping LIDC-IDRI-0806
#
# Processing LIDC-IDRI-0805
# Loading dicom files ... This may take a moment.
# Processing Patients:  83%|████████▎ | 850/1018 [37:13<20:47,  7.43s/it]
# Processing LIDC-IDRI-0804
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▎ | 851/1018 [37:19<19:57,  7.17s/it]
# Skipping LIDC-IDRI-0803
#
# Processing LIDC-IDRI-0802
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▍ | 853/1018 [37:29<17:57,  6.53s/it]
# Processing LIDC-IDRI-0801
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▍ | 854/1018 [37:48<24:08,  8.84s/it]
# Skipping LIDC-IDRI-0800
#
# Processing LIDC-IDRI-0799
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▍ | 856/1018 [38:00<20:58,  7.77s/it]
# Skipping LIDC-IDRI-0798
#
# Processing LIDC-IDRI-0797
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▍ | 858/1018 [38:14<20:05,  7.53s/it]
# Processing LIDC-IDRI-0796
# Loading dicom files ... This may take a moment.
# Processing Patients:  84%|████████▍ | 859/1018 [38:27<22:41,  8.56s/it]
# Skipping LIDC-IDRI-0795
# Skipping LIDC-IDRI-0794
#
# Processing LIDC-IDRI-0793
# Loading dicom files ... This may take a moment.
# Processing Patients:  85%|████████▍ | 862/1018 [38:47<20:14,  7.78s/it]
# Processing LIDC-IDRI-0792
# Loading dicom files ... This may take a moment.
# Processing Patients:  85%|████████▍ | 863/1018 [39:08<25:53, 10.02s/it]
# Processing LIDC-IDRI-0791
# Loading dicom files ... This may take a moment.
# Processing Patients:  85%|████████▍ | 864/1018 [39:21<27:36, 10.76s/it]
# Skipping LIDC-IDRI-0790
#
# Processing LIDC-IDRI-0789
# Loading dicom files ... This may take a moment.
# Processing Patients:  85%|████████▌ | 866/1018 [39:36<23:55,  9.44s/it]
# Skipping LIDC-IDRI-0788
# Skipping LIDC-IDRI-0787
#
# Processing LIDC-IDRI-0786
# Loading dicom files ... This may take a moment.
# Processing Patients:  85%|████████▌ | 869/1018 [39:40<14:43,  5.93s/it]
# Skipping LIDC-IDRI-0785
#
# Processing LIDC-IDRI-0784
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 871/1018 [39:54<15:08,  6.18s/it]
# Processing LIDC-IDRI-0783
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 872/1018 [40:01<15:36,  6.41s/it]
# Skipping LIDC-IDRI-0782
#
# Processing LIDC-IDRI-0781
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 874/1018 [40:11<14:21,  5.98s/it]
# Processing LIDC-IDRI-0780
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 875/1018 [40:22<16:31,  6.93s/it]
# Processing LIDC-IDRI-0779
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 876/1018 [40:28<15:54,  6.72s/it]
# Processing LIDC-IDRI-0778
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▌ | 877/1018 [40:43<20:07,  8.57s/it]
# Skipping LIDC-IDRI-0777
#
# Processing LIDC-IDRI-0776
# Loading dicom files ... This may take a moment.
# Processing Patients:  86%|████████▋ | 879/1018 [40:55<17:29,  7.55s/it]
# Skipping LIDC-IDRI-0775
#
# Processing LIDC-IDRI-0774
# Loading dicom files ... This may take a moment.
# Processing Patients:  87%|████████▋ | 881/1018 [41:02<13:42,  6.01s/it]
# Skipping LIDC-IDRI-0773
# Skipping LIDC-IDRI-0772
#
# Processing LIDC-IDRI-0771
# Loading dicom files ... This may take a moment.
# Processing Patients:  87%|████████▋ | 884/1018 [41:10<10:12,  4.57s/it]
# Skipping LIDC-IDRI-0770
#
# Processing LIDC-IDRI-0769
# Loading dicom files ... This may take a moment.
# Processing Patients:  87%|████████▋ | 886/1018 [41:15<08:52,  4.03s/it]
# Skipping LIDC-IDRI-0768
#
# Processing LIDC-IDRI-0767
# Loading dicom files ... This may take a moment.
# Processing Patients:  87%|████████▋ | 888/1018 [41:21<07:55,  3.66s/it]
# Skipping LIDC-IDRI-0766
# Skipping LIDC-IDRI-0765
#
# Processing LIDC-IDRI-0764
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 891/1018 [41:25<05:50,  2.76s/it]
# Processing LIDC-IDRI-0763
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 892/1018 [41:34<07:44,  3.68s/it]
# Skipping LIDC-IDRI-0762
# Skipping LIDC-IDRI-0761
#
# Processing LIDC-IDRI-0760
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 895/1018 [41:38<05:52,  2.86s/it]
# Skipping LIDC-IDRI-0759
#
# Processing LIDC-IDRI-0758
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 897/1018 [41:52<07:54,  3.92s/it]
# Processing LIDC-IDRI-0757
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 898/1018 [42:08<11:46,  5.88s/it]
# Processing LIDC-IDRI-0756
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 899/1018 [42:23<15:17,  7.71s/it]
# Processing LIDC-IDRI-0755
# Loading dicom files ... This may take a moment.
# Processing Patients:  88%|████████▊ | 900/1018 [42:27<13:30,  6.87s/it]
# Skipping LIDC-IDRI-0754
#
# Processing LIDC-IDRI-0753
# Loading dicom files ... This may take a moment.
# Processing Patients:  89%|████████▊ | 902/1018 [42:33<10:23,  5.37s/it]
# Processing LIDC-IDRI-0752
# Loading dicom files ... This may take a moment.
# Processing Patients:  89%|████████▊ | 903/1018 [42:39<10:46,  5.62s/it]
# Skipping LIDC-IDRI-0751
# Skipping LIDC-IDRI-0750
# Skipping LIDC-IDRI-0749
# Skipping LIDC-IDRI-0748
# Skipping LIDC-IDRI-0747
#
# Processing LIDC-IDRI-0746
# Loading dicom files ... This may take a moment.
# Processing Patients:  89%|████████▉ | 909/1018 [42:43<04:14,  2.33s/it]
# Processing LIDC-IDRI-0745
# Loading dicom files ... This may take a moment.
# Processing Patients:  89%|████████▉ | 910/1018 [42:46<04:32,  2.53s/it]
# Processing LIDC-IDRI-0744
# Loading dicom files ... This may take a moment.
# Processing Patients:  89%|████████▉ | 911/1018 [43:09<10:15,  5.75s/it]
# Processing LIDC-IDRI-0743
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|████████▉ | 912/1018 [43:16<10:29,  5.94s/it]
# Skipping LIDC-IDRI-0742
#
# Processing LIDC-IDRI-0741
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|████████▉ | 914/1018 [43:26<09:55,  5.73s/it]
# Skipping LIDC-IDRI-0740
#
# Processing LIDC-IDRI-0739
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|████████▉ | 916/1018 [43:42<10:47,  6.35s/it]
# Processing LIDC-IDRI-0738
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|█████████ | 917/1018 [43:44<09:30,  5.65s/it]
# Processing LIDC-IDRI-0737
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|█████████ | 918/1018 [43:47<08:13,  4.94s/it]
# Skipping LIDC-IDRI-0736
#
# Processing LIDC-IDRI-0735
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|█████████ | 920/1018 [43:52<06:44,  4.13s/it]
# Processing LIDC-IDRI-0734
# Loading dicom files ... This may take a moment.
# Processing Patients:  90%|█████████ | 921/1018 [44:02<08:41,  5.38s/it]
# Processing LIDC-IDRI-0733
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 922/1018 [44:18<12:25,  7.77s/it]
# Skipping LIDC-IDRI-0732
#
# Processing LIDC-IDRI-0731
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 924/1018 [44:28<10:23,  6.63s/it]
# Processing LIDC-IDRI-0730
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 925/1018 [44:33<09:52,  6.37s/it]
# Processing LIDC-IDRI-0729
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 926/1018 [44:41<10:25,  6.80s/it]
# Processing LIDC-IDRI-0728
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 927/1018 [44:56<13:14,  8.73s/it]
# Processing LIDC-IDRI-0727
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████ | 928/1018 [45:13<16:26, 10.96s/it]
# Processing LIDC-IDRI-0726
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████▏| 929/1018 [45:27<17:28, 11.78s/it]
# Processing LIDC-IDRI-0725
# Loading dicom files ... This may take a moment.
# Processing Patients:  91%|█████████▏| 930/1018 [45:34<15:31, 10.59s/it]
# Skipping LIDC-IDRI-0724
# Skipping LIDC-IDRI-0723
#
# Processing LIDC-IDRI-0722
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 933/1018 [45:53<11:36,  8.20s/it]
# Skipping LIDC-IDRI-0721
#
# Processing LIDC-IDRI-0720
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 935/1018 [46:04<10:08,  7.33s/it]
# Skipping LIDC-IDRI-0719
#
# Processing LIDC-IDRI-0718
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 937/1018 [46:12<08:21,  6.19s/it]
# Processing LIDC-IDRI-0717
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 938/1018 [46:29<11:00,  8.26s/it]
# Processing LIDC-IDRI-0716
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 939/1018 [46:33<09:39,  7.33s/it]
# Processing LIDC-IDRI-0715
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 940/1018 [46:51<12:45,  9.81s/it]
# Processing LIDC-IDRI-0714
# Loading dicom files ... This may take a moment.
# Processing Patients:  92%|█████████▏| 941/1018 [46:58<11:51,  9.24s/it]
# Skipping LIDC-IDRI-0713
# Skipping LIDC-IDRI-0712
#
# Processing LIDC-IDRI-0711
# Loading dicom files ... This may take a moment.
# Processing Patients:  93%|█████████▎| 944/1018 [47:03<06:24,  5.19s/it]
# Processing LIDC-IDRI-0710
# Loading dicom files ... This may take a moment.
# Processing Patients:  93%|█████████▎| 945/1018 [47:17<08:36,  7.07s/it]
# Skipping LIDC-IDRI-0709
# Skipping LIDC-IDRI-0708
# Skipping LIDC-IDRI-0707
# Skipping LIDC-IDRI-0706
# Skipping LIDC-IDRI-0705
#
# Processing LIDC-IDRI-0704
# Loading dicom files ... This may take a moment.
# Processing Patients:  93%|█████████▎| 951/1018 [47:35<05:00,  4.48s/it]
# Processing LIDC-IDRI-0703
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▎| 952/1018 [47:45<05:46,  5.25s/it]
# Processing LIDC-IDRI-0702
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▎| 953/1018 [48:07<08:24,  7.77s/it]
# Processing LIDC-IDRI-0701
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▎| 954/1018 [48:20<09:25,  8.83s/it]
# Processing LIDC-IDRI-0700
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 955/1018 [48:39<11:20, 10.80s/it]
# Processing LIDC-IDRI-0699
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 956/1018 [48:45<10:09,  9.83s/it]
# Processing LIDC-IDRI-0698
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 957/1018 [49:02<11:50, 11.65s/it]
# Processing LIDC-IDRI-0697
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 958/1018 [49:10<10:32, 10.54s/it]
# Processing LIDC-IDRI-0696
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 959/1018 [49:23<11:09, 11.34s/it]
# Skipping LIDC-IDRI-0695
# Skipping LIDC-IDRI-0694
#
# Processing LIDC-IDRI-0693
# Loading dicom files ... This may take a moment.
# Processing Patients:  94%|█████████▍| 962/1018 [49:27<05:32,  5.93s/it]
# Skipping LIDC-IDRI-0692
#
# Processing LIDC-IDRI-0691
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▍| 964/1018 [49:31<04:04,  4.52s/it]
# Processing LIDC-IDRI-0690
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▍| 965/1018 [49:34<03:50,  4.34s/it]
# Processing LIDC-IDRI-0689
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▍| 966/1018 [49:42<04:27,  5.15s/it]
# Processing LIDC-IDRI-0688
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▍| 967/1018 [49:55<05:56,  6.99s/it]
# Skipping LIDC-IDRI-0687
# Skipping LIDC-IDRI-0686
#
# Processing LIDC-IDRI-0685
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▌| 970/1018 [49:58<03:12,  4.01s/it]
# Processing LIDC-IDRI-0684
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▌| 971/1018 [50:15<05:06,  6.52s/it]
# Processing LIDC-IDRI-0683
# Loading dicom files ... This may take a moment.
# Processing Patients:  95%|█████████▌| 972/1018 [50:18<04:24,  5.76s/it]
# Processing LIDC-IDRI-0682
# Loading dicom files ... This may take a moment.
# Processing Patients:  96%|█████████▌| 973/1018 [50:27<04:44,  6.33s/it]
# Processing LIDC-IDRI-0681
# Loading dicom files ... This may take a moment.
# Processing Patients:  96%|█████████▌| 974/1018 [50:43<06:32,  8.93s/it]
# Skipping LIDC-IDRI-0680
#
# Processing LIDC-IDRI-0679
# Loading dicom files ... This may take a moment.
# Processing Patients:  96%|█████████▌| 976/1018 [50:47<04:10,  5.95s/it]
# Skipping LIDC-IDRI-0678
# Skipping LIDC-IDRI-0677
#
# Processing LIDC-IDRI-0676
# Loading dicom files ... This may take a moment.
# Processing Patients:  96%|█████████▌| 979/1018 [51:01<03:27,  5.31s/it]
# Skipping LIDC-IDRI-0675
# Skipping LIDC-IDRI-0674
#
# Processing LIDC-IDRI-0673
# Loading dicom files ... This may take a moment.
# Processing Patients:  96%|█████████▋| 982/1018 [51:21<03:30,  5.85s/it]
# Processing LIDC-IDRI-0672
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 983/1018 [51:34<04:08,  7.10s/it]
# Skipping LIDC-IDRI-0671
#
# Processing LIDC-IDRI-0670
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 985/1018 [51:39<03:07,  5.69s/it]
# Processing LIDC-IDRI-0669
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 986/1018 [51:55<03:57,  7.42s/it]
# Processing LIDC-IDRI-0668
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 987/1018 [51:58<03:24,  6.60s/it]
# Processing LIDC-IDRI-0667
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 988/1018 [52:08<03:44,  7.47s/it]
# Skipping LIDC-IDRI-0666
#
# Processing LIDC-IDRI-0665
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 990/1018 [52:28<03:56,  8.45s/it]
# Processing LIDC-IDRI-0664
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 991/1018 [52:45<04:39, 10.35s/it]
# Processing LIDC-IDRI-0663
# Loading dicom files ... This may take a moment.
# Processing Patients:  97%|█████████▋| 992/1018 [53:03<05:14, 12.08s/it]
# Skipping LIDC-IDRI-0662
# Skipping LIDC-IDRI-0661
# Skipping LIDC-IDRI-0660
# Skipping LIDC-IDRI-0659
#
# Processing LIDC-IDRI-0658
# Loading dicom files ... This may take a moment.
# Processing Patients:  98%|█████████▊| 997/1018 [53:14<02:01,  5.79s/it]
# Processing LIDC-IDRI-0657
# Loading dicom files ... This may take a moment.
# Processing Patients:  98%|█████████▊| 998/1018 [53:27<02:20,  7.00s/it]
# Skipping LIDC-IDRI-0656
#
# Processing LIDC-IDRI-0655
# Loading dicom files ... This may take a moment.
# Processing Patients:  98%|█████████▊| 1000/1018 [54:01<02:59,  9.95s/it]
# Skipping LIDC-IDRI-0654
#
# Processing LIDC-IDRI-0653
# Loading dicom files ... This may take a moment.
# Processing Patients:  98%|█████████▊| 1002/1018 [54:04<01:59,  7.49s/it]
# Skipping LIDC-IDRI-0652
#
# Processing LIDC-IDRI-0651
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▊| 1004/1018 [54:28<02:03,  8.85s/it]
# Processing LIDC-IDRI-0650
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▊| 1005/1018 [54:36<01:52,  8.62s/it]
# Skipping LIDC-IDRI-0649
#
# Processing LIDC-IDRI-0648
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▉| 1007/1018 [55:06<01:58, 10.80s/it]
# Processing LIDC-IDRI-0647
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▉| 1008/1018 [55:17<01:49, 10.91s/it]
# Processing LIDC-IDRI-0646
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▉| 1009/1018 [55:26<01:33, 10.42s/it]
# Skipping LIDC-IDRI-0645
#
# Processing LIDC-IDRI-0644
# Loading dicom files ... This may take a moment.
# Processing Patients:  99%|█████████▉| 1011/1018 [55:31<00:51,  7.30s/it]
# Skipping LIDC-IDRI-0643
# Skipping LIDC-IDRI-0642
# Skipping LIDC-IDRI-0641
# Skipping LIDC-IDRI-0640
#
# Processing LIDC-IDRI-0639
# Loading dicom files ... This may take a moment.
# Processing Patients: 100%|██████████| 1018/1018 [55:40<00:00,  3.28s/it]
# Skipping LIDC-IDRI-0638

# %% [markdown]
# ##34. Final Verification

# %%
dataset = pd.read_csv(metadata_csv)

print(dataset.shape)

dataset.head()
# Out:
# (2040, 11)
#         PatientID  NoduleID  \
# 0  LIDC-IDRI-0078         1
# 1  LIDC-IDRI-0078         2
# 2  LIDC-IDRI-0078         4
# 3  LIDC-IDRI-0069         1
# 4  LIDC-IDRI-0069         3
#
#                                            PatchPath    PatchShape  Readers  \
# 0  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...  (74, 84, 10)        4
# 1  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...  (80, 67, 10)        4
# 2  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...  (90, 80, 12)        4
# 3  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...  (66, 59, 13)        4
# 4  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...  (69, 83, 15)        4
#
#    MeanMalignancy  MedianMalignancy  CancerLabel  \
# 0            3.75               3.5            0
# 1            3.75               3.5            0
# 2            4.25               4.5            1
# 3            3.25               3.0            0
# 4            3.50               3.5            0
#
#                                      MaskedPatchPath  \
# 0  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...
# 1  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...
# 2  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...
# 3  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...
# 4  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...
#
#                                             MaskPath  MaskVoxelCount
# 0  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...            1903
# 1  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...            1741
# 2  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...            3646
# 3  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...             521
# 4  C:\Users\Dell\Desktop\Colab_Notebook\Dataset\P...            1629

# %% [markdown]
# ##35. verify Path Files

# %%
missing = []

for path in dataset["PatchPath"]:

    if not os.path.exists(path):
        missing.append(path)

print("Missing patches:", len(missing))
# Out:
# Missing patches: 0

# %% [markdown]
# ##36. Dataset Statistics

# %%
print(dataset["CancerLabel"].value_counts())

print()

print(dataset["MeanMalignancy"].describe())
# Out:
# CancerLabel
# 0    1775
# 1     265
# Name: count, dtype: int64
#
# count    2040.000000
# mean        2.770700
# std         0.928866
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.250000
# max         5.000000
# Name: MeanMalignancy, dtype: float64

# %%
dataset = pd.read_csv(DATASET_FILE)

print("="*60)

print("SUMMARY")

print("="*60)

print()

print("Patients completed")

print(
    processing_log.Status.value_counts()
)

print()

print("Unique patients")

print(
    dataset.PatientID.nunique()
)

print()

print("Total nodules")

print(len(dataset))

print()

print("Cancer labels")

print(
    dataset.CancerLabel.value_counts()
)

print()

print("Missing patches")

print(

    dataset.PatchPath.apply(
        lambda x: not Path(x).exists()
    ).sum()

)

print()

print("Missing masks")

print(

    dataset.MaskPath.apply(
        lambda x: not Path(x).exists()
    ).sum()

)
# Out:
# ============================================================
# SUMMARY
# ============================================================
#
# Patients completed
# Status
# Completed    1014
# Name: count, dtype: int64
#
# Unique patients
# 840
#
# Total nodules
# 2040
#
# Cancer labels
# CancerLabel
# 0    1775
# 1     265
# Name: count, dtype: int64
#
# Missing patches
# 0
#
# Missing masks
# 0
