# %% [markdown]
# ###Objective
#
# Generate the final dataset that will be used for deep learning.
#
# Input:
#
# * Original CT DICOM scans
# * pylidc annotations
#
# Output:
#
# * Cropped 3D lung nodule volumes (.npy)
# * Metadata CSV containing labels and patch paths

# %% [markdown]
# ##1. mount Google Drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##2. Install Packages

# %%
# !pip install -q pylidc pydicom scipy scikit-image tqdm

# %% [markdown]
# ##3. Import Required Libraries

# %%
import os
from pathlib import Path

config_path = Path("/root/.pylidcrc")

config_content = """
[dicom]
path = /content/drive/MyDrive/Dissertation/Dataset/Raw
"""

config_path.write_text(config_content)

print("Created:", config_path)

print(config_path.read_text())
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import configparser
if not hasattr(configparser, "SafeConfigParser"):
    configparser.SafeConfigParser = configparser.ConfigParser

from tqdm import tqdm
# Out:
# Created: /root/.pylidcrc
#
# [dicom]
# path = /content/drive/MyDrive/Dissertation/Dataset/Raw

# %% [markdown]
# ##4. NumPy Compatibility

# %%
if not hasattr(np, "int"):
    np.int = int

if not hasattr(np, "float"):
    np.float = float

if not hasattr(np, "bool"):
    np.bool = bool
import pylidc as pl

# %% [markdown]
# ##5. Dataset Path

# %%
RAW_PATH = Path(
    "/content/drive/MyDrive/Dissertation/Dataset/Raw"
)

PROCESSED_PATH = Path(
    "/content/drive/MyDrive/Dissertation/Dataset/Processed"
)

PATCH_PATH = PROCESSED_PATH / "NodulePatches"

PATCH_PATH.mkdir(
    parents=True,
    exist_ok=True
)

MASK_PATH = (
    PROCESSED_PATH /
    "NoduleMasks"
)

MASK_PATH.mkdir(
    parents=True,
    exist_ok=True
)

# %% [markdown]
# ##6. Load Database

# %%
scans = pl.query(pl.Scan).all()

print("Total scans:", len(scans))
# Out:
# Total scans: 1018

# %% [markdown]
# ##7. Create Patient Lookup

# %%
patient_folders = sorted([
    p.name
    for p in RAW_PATH.iterdir()
    if p.is_dir()
])

print(patient_folders)
# Out:
# ['LIDC-IDRI-0001', 'LIDC-IDRI-0002', 'LIDC-IDRI-0003', 'LIDC-IDRI-0004', 'LIDC-IDRI-0005', 'LIDC-IDRI-0006', 'LIDC-IDRI-0007', 'LIDC-IDRI-0008', 'LIDC-IDRI-0009', 'LIDC-IDRI-0010']

# %% [markdown]
# ##8. Keep Only Available Patients

# %%
available_scans = []

for scan in scans:

    if scan.patient_id in patient_folders:

        available_scans.append(scan)

print("Available scans:", len(available_scans))
# Out:
# Available scans: 10

# %%
##9. Select First Patient

# %%
scan = available_scans[0]

print("Patient:", scan.patient_id)

print("Study UID:", scan.study_instance_uid)

print("Series UID:", scan.series_instance_uid)
# Out:
# Patient: LIDC-IDRI-0001
# Study UID: 1.3.6.1.4.1.14519.5.2.1.6279.6001.298806137288633453246975630178
# Series UID: 1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636438705059720603192

# %% [markdown]
# ##10. Cluser Annotations

# %%
clusters = scan.cluster_annotations()

print("Clusters:", len(clusters))

for i, cluster in enumerate(clusters):

    print(
        f"Cluster {i+1}:",
        len(cluster),
        "reader(s)"
    )
# Out:
# Clusters: 1
# Cluster 1: 4 reader(s)

# %% [markdown]
# ##11. Select One Physical Nodule

# %%
cluster = clusters[0]

print("Number of annotations:", len(cluster))
# Out:
# Number of annotations: 4

# %% [markdown]
# ##12. Consensus Malignancy

# %%
malignancy_scores = [
    ann.malignancy
    for ann in cluster
]

print("Reader Scores:")

print(malignancy_scores)

print()

print(
    "Mean:",
    np.mean(malignancy_scores)
)

print(
    "Median:",
    np.median(malignancy_scores)
)
# Out:
# Reader Scores:
# [5, 5, 5, 4]
#
# Mean: 4.75
# Median: 5.0

# %% [markdown]
# ##13. Load CT Voulume

# %%
volume = scan.to_volume()

print("Volume shape:", volume.shape)

print("Data type:", volume.dtype)

print("Minimum:", volume.min())

print("Maximum:", volume.max())
# Out:
# Loading dicom files ... This may take a moment.
# Volume shape: (512, 512, 133)
# Data type: int16
# Minimum: -2048
# Maximum: 3071

# %% [markdown]
# ##14. Generate Consensus Mask
# pylidc provides multiple annotations from multiple radiologists. We need to combine them into a single consensus mask.

# %%
from pylidc.utils import consensus
mask, bbox, masks = consensus(
    cluster,
    clevel=0.5,
    pad=[(0,0),(0,0),(0,0)]
)

print("Mask shape:", mask.shape)

print("Bounding box:")
print(bbox)
# Out:
# Mask shape: (52, 44, 9)
# Bounding box:
# (slice(np.int64(340), np.int64(392), None), slice(np.int64(297), np.int64(341), None), slice(np.int64(86), np.int64(95), None))

# %% [markdown]
# ##15. Verify Mask Dimensions

# %%
print("CT volume:")
print(volume.shape)

print()

print("Mask:")
print(mask.shape)
# Out:
# CT volume:
# (512, 512, 133)
#
# Mask:
# (52, 44, 9)

# %% [markdown]
# ##16. Extract Nodule Patch

# %%
nodule_patch = volume[
    bbox[0],
    bbox[1],
    bbox[2]
]

print(
    "Nodule patch shape:",
    nodule_patch.shape
)
# Out:
# Nodule patch shape: (52, 44, 9)

# %% [markdown]
# ##17. Confirm Patch and Mask Alignment

# %%
print(
    "Patch:",
    nodule_patch.shape
)

print(
    "Mask:",
    mask.shape
)
# Out:
# Patch: (52, 44, 9)
# Mask: (52, 44, 9)

# %% [markdown]
# ##18. Visualize Extracted Nodule

# %%
middle = nodule_patch.shape[2] // 2


plt.figure(figsize=(12,5))


plt.subplot(1,2,1)

plt.imshow(
    nodule_patch[:,:,middle],
    cmap="gray"
)

plt.title("Extracted CT Nodule")

plt.axis("off")



plt.subplot(1,2,2)

plt.imshow(
    mask[:,:,middle],
    cmap="gray"
)

plt.title("Consensus Mask")

plt.axis("off")


plt.show()

# %% [markdown]
# ##19. Apply Mask

# %%
masked_patch = nodule_patch.copy()

masked_patch[mask == False] = -1024

# %% [markdown]
# ####Visualize:

# %%
plt.figure(figsize=(5,5))

plt.imshow(
    masked_patch[:,:,middle],
    cmap="gray"
)

plt.title("Masked Nodule")

plt.axis("off")

plt.show()

# %% [markdown]
# ##20. Save First Test Patch

# %%
test_file = (
    PATCH_PATH /
    f"{scan.patient_id}_nodule_test.npy"
)


np.save(
    test_file,
    masked_patch
)


print(
    "Saved:",
    test_file
)
# Out:
# Saved: /content/drive/MyDrive/Dissertation/Dataset/Processed/NodulePatches/LIDC-IDRI-0001_nodule_test.npy

# %% [markdown]
# ##21. Create Extraction Function
#
# ####Function 1: Convert malignancy score to binary label

# %%
def malignancy_label(score):

    if score >= 4:
        return 1   # malignant

    else:
        return 0   # benign

# %% [markdown]
# ##22. Create Nodule Extraction Function

# %%
def extract_nodule(
    volume,
    scan,
    cluster,
    save_path,
    nodule_id
):

    try:

        # Generate consensus mask
        mask, bbox, _ = consensus(
            cluster,
            clevel=0.5
        )



        # Crop CT
        patch = volume[
            bbox[0],
            bbox[1],
            bbox[2]
        ]

        mask = mask.astype(np.uint8)


        # Apply mask
        raw_patch = patch.copy()

        masked_patch = patch.copy()
        masked_patch[mask == 0] = -1024


        # Save
        filename = (
            f"{scan.patient_id}_"
            f"nodule_{nodule_id:03d}.npy"
        )


        filepath = save_path / filename


        np.save(
            filepath,
            raw_patch
        )

        mask_file = (
            MASK_PATH /
            f"{scan.patient_id}_nodule_{nodule_id:03d}_mask.npy"
        )

        np.save(
            mask_file,
            masked_patch
        )



        # Malignancy information

        scores = [
            ann.malignancy
            for ann in cluster
        ]


        mean_malignancy = np.mean(scores)


        return {

            "PatientID":
                scan.patient_id,

            "NoduleID":
                nodule_id,

            "PatchPath":
                str(filepath),

            "PatchShape":
                str(patch.shape),

            "Readers":
                len(cluster),

            "MeanMalignancy":
                mean_malignancy,

            "MedianMalignancy":
                np.median(scores),

            "CancerLabel":
                malignancy_label(
                    mean_malignancy
                ),

            "MaskedPatchPath": str(mask_file),

            "MaskPath": str(mask_file),

        }


    except Exception as e:

        print(
            "Failed:",
            scan.patient_id,
            nodule_id,
            e
        )

        return None

# %% [markdown]
# ##23. Test Function on Current Patient

# %%
# Load CT once
volume = scan.to_volume()
test_result = extract_nodule(
    volume,
    scan,
    cluster,
    PATCH_PATH,
    1
)

test_result
# Out:
# Loading dicom files ... This may take a moment.
# {'PatientID': 'LIDC-IDRI-0001',
#  'NoduleID': 1,
#  'PatchPath': '/content/drive/MyDrive/Dissertation/Dataset/Processed/NodulePatches/LIDC-IDRI-0001_nodule_001.npy',
#  'PatchShape': '(52, 44, 9)',
#  'Readers': 4,
#  'MeanMalignancy': np.float64(4.75),
#  'MedianMalignancy': np.float64(5.0),
#  'CancerLabel': 1,
#  'MaskedPatchPath': '/content/drive/MyDrive/Dissertation/Dataset/Processed/NoduleMasks/LIDC-IDRI-0001_nodule_001_mask.npy',
#  'MaskPath': '/content/drive/MyDrive/Dissertation/Dataset/Processed/NoduleMasks/LIDC-IDRI-0001_nodule_001_mask.npy'}

# %% [markdown]
# ##24. Process All Available Scans

# %%
all_records = []


for scan in tqdm(
    available_scans,
    desc="Processing patients"
):


    print(
        "\nProcessing:",
        scan.patient_id
    )

     # Load CT once
    volume = scan.to_volume()

    clusters = scan.cluster_annotations()


    for idx, cluster in enumerate(clusters):


        result = extract_nodule(
            volume,
            scan,
            cluster,
            PATCH_PATH,
            idx+1
        )


        if result is not None:

            all_records.append(
                result
            )
# Out:
# Processing patients:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing: LIDC-IDRI-0001
# Loading dicom files ... This may take a moment.
# Processing patients:  10%|█         | 1/10 [00:02<00:20,  2.32s/it]
# Processing: LIDC-IDRI-0002
# Loading dicom files ... This may take a moment.
# Processing patients:  20%|██        | 2/10 [00:19<01:28, 11.11s/it]
# Processing: LIDC-IDRI-0003
# Loading dicom files ... This may take a moment.
# Processing patients:  30%|███       | 3/10 [00:42<01:55, 16.48s/it]
# Processing: LIDC-IDRI-0004
# Loading dicom files ... This may take a moment.
# Processing patients:  40%|████      | 4/10 [00:58<01:37, 16.17s/it]
# Processing: LIDC-IDRI-0005
# Loading dicom files ... This may take a moment.
# Processing patients:  50%|█████     | 5/10 [01:19<01:29, 17.95s/it]
# Processing: LIDC-IDRI-0006
# Loading dicom files ... This may take a moment.
# Processing patients:  60%|██████    | 6/10 [01:37<01:11, 17.89s/it]
# Processing: LIDC-IDRI-0007
# Loading dicom files ... This may take a moment.
# Processing patients:  70%|███████   | 7/10 [01:57<00:56, 18.88s/it]
# Processing: LIDC-IDRI-0008
# Loading dicom files ... This may take a moment.
# Processing patients:  80%|████████  | 8/10 [02:21<00:40, 20.47s/it]
# Processing: LIDC-IDRI-0009
# Loading dicom files ... This may take a moment.
# Processing patients:  90%|█████████ | 9/10 [02:38<00:19, 19.32s/it]
# Processing: LIDC-IDRI-0010
# Loading dicom files ... This may take a moment.
# Processing patients: 100%|██████████| 10/10 [02:57<00:00, 17.71s/it]

# %% [markdown]
# ##25. Convert Results to DataFrame

# %%
dataset_df = pd.DataFrame(
    all_records
)

dataset_df = dataset_df.sort_values(
    ["PatientID", "NoduleID"]
).reset_index(drop=True)


print(
    "Total extracted nodules:",
    len(dataset_df)
)


dataset_df.head()
# Out:
# Total extracted nodules: 23
#         PatientID  NoduleID  \
# 0  LIDC-IDRI-0001         1
# 1  LIDC-IDRI-0002         1
# 2  LIDC-IDRI-0003         1
# 3  LIDC-IDRI-0003         2
# 4  LIDC-IDRI-0003         3
#
#                                            PatchPath    PatchShape  Readers  \
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (52, 44, 9)        4
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...  (45, 50, 28)        2
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (36, 34, 8)        1
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...  (40, 45, 10)        4
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (13, 19, 4)        4
#
#    MeanMalignancy  MedianMalignancy  CancerLabel  \
# 0            4.75               5.0            1
# 1            4.50               4.5            1
# 2            2.00               2.0            0
# 3            4.25               4.5            1
# 4            3.25               3.5            0
#
#                                      MaskedPatchPath  \
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...
#
#                                             MaskPath
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...

# %% [markdown]
# ##26. Check Class Distribution

# %%
dataset_df["CancerLabel"].value_counts()
# Out:
# CancerLabel
# 0    18
# 1     5
# Name: count, dtype: int64

# %% [markdown]
# ##27. Save Metadata CSV

# %%
metadata_output = (
    PROCESSED_PATH /
    "nodule_dataset.csv"
)


dataset_df.to_csv(
    metadata_output,
    index=False
)


print(
    "Saved:",
    metadata_output
)
# Out:
# Saved: /content/drive/MyDrive/Dissertation/Dataset/Processed/nodule_dataset.csv

# %% [markdown]
# ##28. Import Required Packages

# %%
import gc
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ##29. Create Output Directories

# %%
PATCH_PATH = (
    PROCESSED_PATH /
    "NodulePatches"
)

PATCH_PATH.mkdir(
    parents=True,
    exist_ok=True
)

# %% [markdown]
# ##30. Metadata File

# %%
metadata_csv = (
    PROCESSED_PATH /
    "nodule_dataset.csv"
)

# %% [markdown]
# ##31. Resume Capability
# ####If Colab disconnects after processing 500 patients the notebook simply continues.

# %%
processed_patients = set()

if metadata_csv.exists():

    existing = pd.read_csv(metadata_csv)

    processed_patients = set(
        existing["PatientID"].unique()
    )

print(
    "Already processed:",
    len(processed_patients)
)
# Out:
# Already processed: 10

# %% [markdown]
# ##32. Metadata Buffer

# %%
records = []

# %% [markdown]
# ##33. Optimized Main Loop

# %%
for scan in tqdm(
    scans,
    desc="Processing Patients"
):

    if scan.patient_id not in patient_folders:
        continue

    if scan.patient_id in processed_patients:
        print(f"Skipping {scan.patient_id}")
        continue

    print(f"\nProcessing {scan.patient_id}")

    try:

        # Load CT only once
        volume = scan.to_volume()

        clusters = scan.cluster_annotations()

        patient_records = []

        for idx, cluster in enumerate(clusters):

            result = extract_nodule(
                volume,
                scan,
                cluster,
                PATCH_PATH,
                idx + 1
            )

            if result is not None:
                patient_records.append(result)

        # Save metadata immediately
        if len(patient_records) > 0:

            df = pd.DataFrame(patient_records)

            if metadata_csv.exists():

                df.to_csv(
                    metadata_csv,
                    mode="a",
                    header=False,
                    index=False
                )

            else:

                df.to_csv(
                    metadata_csv,
                    index=False
                )

        del volume
        gc.collect()

    except Exception as e:

        print(
            scan.patient_id,
            e
        )
# Out:
# Processing Patients: 100%|██████████| 1018/1018 [00:00<00:00, 425787.94it/s]
# Skipping LIDC-IDRI-0001
# Skipping LIDC-IDRI-0002
# Skipping LIDC-IDRI-0003
# Skipping LIDC-IDRI-0004
# Skipping LIDC-IDRI-0005
# Skipping LIDC-IDRI-0006
# Skipping LIDC-IDRI-0007
# Skipping LIDC-IDRI-0008
# Skipping LIDC-IDRI-0009
# Skipping LIDC-IDRI-0010

# %% [markdown]
# ##34. Final Verification

# %%
dataset = pd.read_csv(metadata_csv)

print(dataset.shape)

dataset.head()
# Out:
# (23, 10)
#         PatientID  NoduleID  \
# 0  LIDC-IDRI-0001         1
# 1  LIDC-IDRI-0002         1
# 2  LIDC-IDRI-0003         1
# 3  LIDC-IDRI-0003         2
# 4  LIDC-IDRI-0003         3
#
#                                            PatchPath    PatchShape  Readers  \
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (52, 44, 9)        4
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...  (45, 50, 28)        2
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (36, 34, 8)        1
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...  (40, 45, 10)        4
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...   (13, 19, 4)        4
#
#    MeanMalignancy  MedianMalignancy  CancerLabel  \
# 0            4.75               5.0            1
# 1            4.50               4.5            1
# 2            2.00               2.0            0
# 3            4.25               4.5            1
# 4            3.25               3.5            0
#
#                                      MaskedPatchPath  \
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...
#
#                                             MaskPath
# 0  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 1  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 2  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 3  /content/drive/MyDrive/Dissertation/Dataset/Pr...
# 4  /content/drive/MyDrive/Dissertation/Dataset/Pr...

# %% [markdown]
# ##35. verify Path Files

# %%
missing = []

for path in dataset["PatchPath"]:

    if not os.path.exists(path):
        missing.append(path)

print("Missing patches:", len(missing))
# Out:
# Missing patches: 0

# %% [markdown]
# ##36. Dataset Statistics

# %%
print(dataset["CancerLabel"].value_counts())

print()

print(dataset["MeanMalignancy"].describe())
# Out:
# CancerLabel
# 0    18
# 1     5
# Name: count, dtype: int64
#
# count    23.000000
# mean      2.931159
# std       1.077974
# min       1.250000
# 25%       2.000000
# 50%       2.750000
# 75%       3.375000
# max       5.000000
# Name: MeanMalignancy, dtype: float64
